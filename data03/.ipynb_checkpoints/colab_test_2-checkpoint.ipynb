# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusubin/jupyter/blob/master/colab_test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#리눅스에 업로드 df로 읽기

import pandas as pd

df = pd.read_csv("/content/netflix_titles.csv", sep=",")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df2 = pd.read_csv("/content/drive/MyDrive/pythomdata/weather.csv", sep=",")
df2
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
import numpy as np

dates = pd.date_range('20190301', periods=6)
dates
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04',
#                '2019-03-05', '2019-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(data=np.random.randn(6,4),index=dates, columns=['A','B','C','D'])#위에서 생성한 dates (날짜)를 인덱스로 정렬. 
# df=pd.DataFrame(nparray(values), columns=['컬럼명','컬럼명'])
df
# Out:
#                    A         B         C         D
# 2019-03-01 -0.576171  1.389377  1.209594  0.212335
# 2019-03-02  0.114761  0.711306 -0.145880 -0.115574
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-04 -1.192859  0.181014  1.780590  1.109723
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458
# 2019-03-06 -0.365688  0.853494  1.989494 -0.955050

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04',
#                '2019-03-05', '2019-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.index[2]
# Out:
# Timestamp('2019-03-03 00:00:00', freq='D')

# %%
in1=df.index[2]
str(in1)
#리스트를 가지고 만든 여러가지 객체들은 리스트처럼 똑같이 다루어도 크게 문제가 발생하지않는다.
# Out:
# '2019-03-03 00:00:00'

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
a=df['A']
a
# Out:
# 2019-03-01   -0.576171
# 2019-03-02    0.114761
# 2019-03-03    0.346620
# 2019-03-04   -1.192859
# 2019-03-05   -0.661235
# 2019-03-06   -0.365688
# Freq: D, Name: A, dtype: float64

# %%
a[0],a[1]
# Out:
# (-0.5761711918657042, 0.11476091745399382)

# %%
df.values
# Out:
# array([[-0.57617119,  1.38937745,  1.20959359,  0.2123352 ],
#        [ 0.11476092,  0.71130557, -0.14587953, -0.11557392],
#        [ 0.34662023,  0.06928884, -0.94173809, -1.614014  ],
#        [-1.19285908,  0.18101449,  1.78059046,  1.10972269],
#        [-0.66123466, -1.16549564, -0.42836281,  0.41645819],
#        [-0.36568765,  0.85349435,  1.98949425, -0.95504966]])

# %%
df.sort_index(ascending=True)#오름차순
df.sort_index(ascending=False)#내림차순
# Out:
#                    A         B         C         D
# 2019-03-06 -0.365688  0.853494  1.989494 -0.955050
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458
# 2019-03-04 -1.192859  0.181014  1.780590  1.109723
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-02  0.114761  0.711306 -0.145880 -0.115574
# 2019-03-01 -0.576171  1.389377  1.209594  0.212335

# %%
df.sort_values(by='A',ascending=False) #A의 값을 기준으로 내림차순정렬한다.
# Out:
#                    A         B         C         D
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-02  0.114761  0.711306 -0.145880 -0.115574
# 2019-03-06 -0.365688  0.853494  1.989494 -0.955050
# 2019-03-01 -0.576171  1.389377  1.209594  0.212335
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458
# 2019-03-04 -1.192859  0.181014  1.780590  1.109723

# %%
df3=df.copy()
df3
# Out:
#                    A         B         C         D
# 2019-03-01 -0.576171  1.389377  1.209594  0.212335
# 2019-03-02  0.114761  0.711306 -0.145880 -0.115574
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-04 -1.192859  0.181014  1.780590  1.109723
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458
# 2019-03-06 -0.365688  0.853494  1.989494 -0.955050

# %%
# df3를 B로 정렬해주세요!
# df3의 내용이 변경되어야 합니다.
df3=df3.sort_values(by='B',ascending=False) #inplace....
df3
# Out:
#                    A         B         C         D
# 2019-03-01 -0.576171  1.389377  1.209594  0.212335
# 2019-03-06 -0.365688  0.853494  1.989494 -0.955050
# 2019-03-02  0.114761  0.711306 -0.145880 -0.115574
# 2019-03-04 -1.192859  0.181014  1.780590  1.109723
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458

# %%
# 변경된 df3에서 b, c만 추출하여 df4로 저장
df4=df3[['B','C']]
df4
# Out:
#                    B         C
# 2019-03-01  1.389377  1.209594
# 2019-03-06  0.853494  1.989494
# 2019-03-02  0.711306 -0.145880
# 2019-03-04  0.181014  1.780590
# 2019-03-03  0.069289 -0.941738
# 2019-03-05 -1.165496 -0.428363

# %%
# df3의 첫번째 행, 첫번째 열의 값을 1로 수정
df3.iloc[0][0]=1

# df3에서 0행에서 2행까지 추출
df3[0:3] #=df3[0:3,:] 
# df3.iloc[:,0:2]#df3.iloc[추출범위행, 추출범위 열]=> 열로 추출가능
# Out:
#                    A         B
# 2019-03-01  1.000000  1.389377
# 2019-03-06 -0.365688  0.853494
# 2019-03-02  0.114761  0.711306
# 2019-03-04 -1.192859  0.181014
# 2019-03-03  0.346620  0.069289
# 2019-03-05 -0.661235 -1.165496

# %%
# df3에서 2019-03-01, A열의 값을 추출
df3.iloc[0]['A']
df3.loc['2019-03-01','A']
# Out:
# 2019-03-01    1.0
# Name: A, dtype: float64

# %%
# df3에서 2019-03-01, A열, B열의 값을 추출
df3.iloc[0,0:2]
df3.loc['2019-03-01',['A','B']]
# Out:
#               A         B
# 2019-03-01  1.0  1.389377

# %%
# df3에서 A열의 전체 행을 추출

df3[['A']]
df3.loc[:,'A']
# Out:
# 2019-03-01    1.000000
# 2019-03-06   -0.365688
# 2019-03-02    0.114761
# 2019-03-04   -1.192859
# 2019-03-03    0.346620
# 2019-03-05   -0.661235
# Name: A, dtype: float64

# %%
# df3에서 A, C열의 전체 행을 추출
df3[['A','C']]
df3.loc[:,['A','C']]
# Out:
#                    A         C
# 2019-03-01  1.000000  1.209594
# 2019-03-06 -0.365688  1.989494
# 2019-03-02  0.114761 -0.145880
# 2019-03-04 -1.192859  1.780590
# 2019-03-03  0.346620 -0.941738
# 2019-03-05 -0.661235 -0.428363

# %%
# df3에서 0번 행렬 추출
df3.iloc[0,:]
#결과가 1행인 경우 Series로 리턴
#결과가 여러행인 경우 DataFrame으로 리턴
# Out:
# A    1.000000
# B    1.389377
# C    1.209594
# D    0.212335
# Name: 2019-03-01 00:00:00, dtype: float64

# %%
#A행을 추출하여 2번째값을 추출
a=df3.loc[:,'A'][1] #===   a=df3.loc[:,'A'], a[1]
a
# df3.loc[:,'A'].to_list()
#Series는 리스트처럼사용할수있다아

#A행과 C행을 추출하여 1번째 행, 1번째 열의 값을 추출
# b=df3.loc[:,['A','C']]
# b.iloc[1,1]
# Out:
# -0.3656876529121713

# %%
df3.shape
# df3.T
# Out:
# (6, 4)

# %%
# df3에서 5행 전체 전체 열 추출
df3.iloc[5:,:]
# Out:
#                    A         B         C         D
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458

# %%
# df3에서 4행부터 추출
df3.iloc[4:,:]
# Out:
#                    A         B         C         D
# 2019-03-03  0.346620  0.069289 -0.941738 -1.614014
# 2019-03-05 -0.661235 -1.165496 -0.428363  0.416458

# %%
# df3에서 0, 3행, 1부터 2열까지 추출
df3.iloc[[0,3],1:3]
# Out:
#                    B         C
# 2019-03-01  1.389377  1.209594
# 2019-03-04  0.181014  1.780590

# %%
# df3에서 1,2,5행, 1,3열 추출
df5=df.iloc[[1,2,5],[1,3]]

df5
# Out:
#                    B         D
# 2019-03-02  0.711306 -0.115574
# 2019-03-03  0.069289 -1.614014
# 2019-03-06  0.853494 -0.955050
