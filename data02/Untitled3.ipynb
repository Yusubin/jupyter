# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hi\anaconda3\lib\site-packages (4.1.3)
# Requirement already satisfied: trio~=0.17 in c:\users\hi\anaconda3\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\hi\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hi\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.8)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (19.2.0)
# Requirement already satisfied: outcome in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\hi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.1.0)
# Requirement already satisfied: pyOpenSSL>=0.14; extra == "secure" in c:\users\hi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (19.0.0)
# Requirement already satisfied: certifi; extra == "secure" in c:\users\hi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2019.9.11)
# Requirement already satisfied: cryptography>=1.3.4; extra == "secure" in c:\users\hi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\hi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hi\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\hi\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.19)
# Requirement already satisfied: six>=1.5.2 in c:\users\hi\anaconda3\lib\site-packages (from pyOpenSSL>=0.14; extra == "secure"->urllib3[secure,socks]~=1.26->selenium) (1.12.0)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\hi\anaconda3\lib\site-packages (from cryptography>=1.3.4; extra == "secure"->urllib3[secure,socks]~=1.26->selenium) (1.0.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\hi\anaconda3\lib\site-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import datetime

from selenium import webdriver
import time

# %%
CoffeeBean_URL = "https://www.coffeebeankorea.com/store/store.asp"

# %%
def connect():
    CoffeeBean_URL = "https://www.coffeebeankorea.com/store/store.asp"
    wd = webdriver.Chrome('C:/Users/hi/data01/WebDriver/chromedriver.exe') 
    return wd

# %%
def coffee_bean(no):
    wd.get(CoffeeBean_URL)
    shop = ''
    func = 'storePop2("' + str(no) + '")'
    try:
        time.sleep(1)
        wd.execute_script(func)
        time.sleep(1)
        html = wd.page_source
    #     print(html)
        soupCB = BeautifulSoup(html, 'html.parser')
        # #matizCoverLayer0Content > div > div > div.store_txt > h2
        store_name_h2 = soupCB.select("div.store_txt > h2")
        print('1---', store_name_h2)
        store_name = store_name_h2[0].string
        print('2---', store_name)  #매장 이름 출력하기
        store_info = soupCB.select("div.store_txt > table.store_table > tbody > tr > td")
        print('3---', store_info)
        store_address = store_info[2].getText()
        print('4---', store_address)
        store_phone = store_info[3].getText()
        print('5---', store_phone)
        #shop = store_name + ',' + store_address + ',' + store_phone
        shop = []
        shop.append(store_name)
        shop.append(store_address)
        shop.append(store_phone)
        print('크롤링 결과>>>', shop)
    except:
        print('해당번호없음')
    return shop

# %%
wd = None
wd = connect()
shop = coffee_bean(31) #특정번호가 없음.
print(shop)
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   This is separate from the ipykernel package so we can avoid doing imports until
# 1--- [<h2>삼성봉은사거리점</h2>]
# 2--- 삼성봉은사거리점
# 3--- [<td>평일 07:00-22:00 | 주말/공휴일 09:00-22:00</td>, <td>건물뒷편주차장(기계주차식) 평일 최초 30분 2,000원 / 1시간 5,000원 (구매영수증 지참시 30분 2,000원 / 1시간 3,500원 1시간 초과시 10분당 1,000원 ( 평일,주말 동일 )</td>, <td>서울시 강남구 영동대로 607 1,2층  <!--span class="lot">(서울시 강남구 영동대로 607 1,2층)</span--></td>, <td>02-3443-5618</td>]
# 4--- 서울시 강남구 영동대로 607 1,2층
# 5--- 02-3443-5618
# 크롤링 결과>>> ['삼성봉은사거리점', '서울시 강남구 영동대로 607 1,2층  ', '02-3443-5618']
# ['삼성봉은사거리점', '서울시 강남구 영동대로 607 1,2층  ', '02-3443-5618']

# %%
result2 = []
wd = None
wd = connect()
for no in range(1, 20):
    print('=========' + str(no) + '===========')
    shop = coffee_bean(no)
    print(shop)
    if shop != '':
        result2.append(shop)
        print('length>> ', len(result2))
# Out:
# C:\Users\hi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   This is separate from the ipykernel package so we can avoid doing imports until
# =========1===========
# 1--- [<h2>학동역 DT점</h2>]
# 2--- 학동역 DT점
# 3--- [<td>평일 07:00~22:00ㅣ주말/공휴일 08:00~22:00</td>, <td>DT(드라이브 스루) 매장입니다. (주차는 불가)</td>, <td>서울시 강남구 학동로 211 1층  <!--span class="lot">(서울시 강남구 학동로 211 1층)</span--></td>, <td>02-3444-9973</td>]
# 4--- 서울시 강남구 학동로 211 1층
# 5--- 02-3444-9973
# 크롤링 결과>>> ['학동역 DT점', '서울시 강남구 학동로 211 1층  ', '02-3444-9973']
# ['학동역 DT점', '서울시 강남구 학동로 211 1층  ', '02-3444-9973']
# length>>  1
# =========2===========
# 1--- []
# 해당번호없음
#
# =========3===========
# 1--- [<h2>차병원점</h2>]
# 2--- 차병원점
# 3--- [<td>평일 07:00~18:00 | 토요일 07:00~15:00 | 일.공휴일 휴무</td>, <td>병원주차장 이용가능 (병원방문시 무료)</td>, <td>서울시 강남구 논현로 566 강남차병원1층  <!--span class="lot">(서울시 강남구 논현로 566 강남차병원1층)</span--></td>, <td>02-538-7615</td>]
# 4--- 서울시 강남구 논현로 566 강남차병원1층
# 5--- 02-538-7615
# 크롤링 결과>>> ['차병원점', '서울시 강남구 논현로 566 강남차병원1층  ', '02-538-7615']
# ['차병원점', '서울시 강남구 논현로 566 강남차병원1층  ', '02-538-7615']
# length>>  2
# =========4===========
# 1--- []
# 해당번호없음
#
# =========5===========
# 1--- []
# 해당번호없음
#
# =========6===========
# 1--- [<h2>강남대로점</h2>]
# 2--- 강남대로점
# 3--- [<td>월-목 06:30-22:30 | 금 06:30-23:00 I 토 08:00-23:00 I 일 08:00~22:30 </td>, <td>15,000원 이상 구매시 1시간 무료 주차 가능(건물 지하 주차장 이용, 대형 차량 불가)</td>, <td>서울시 서초구 강남대로 369 1층  <!--span class="lot">(서울시 서초구 강남대로 369 1층)</span--></td>, <td>02-588-5778</td>]
# 4--- 서울시 서초구 강남대로 369 1층
# 5--- 02-588-5778
# 크롤링 결과>>> ['강남대로점', '서울시 서초구 강남대로 369 1층  ', '02-588-5778']
# ['강남대로점', '서울시 서초구 강남대로 369 1층  ', '02-588-5778']
# length>>  3
# =========7===========
# 1--- []
# 해당번호없음
#
# =========8===========
# 1--- []
# 해당번호없음
#
# =========9===========
# 1--- []
# 해당번호없음
#
# =========10===========
# 1--- []
# 해당번호없음
#
# =========11===========
# 1--- [<h2>강남에스점</h2>]
# 2--- 강남에스점
# 3--- [<td>월-목 07:00-22:30 | 금 07:00-23:00 I 토 08:00-23:00 I 일 08:00~22:30</td>, <td>무료주차불가</td>, <td>서울시 서초구 서초 1306-3호  <!--span class="lot">(서울시 서초구 서초 1306-3호)</span--></td>, <td>02-593-5095</td>]
# 4--- 서울시 서초구 서초 1306-3호
# 5--- 02-593-5095
# 크롤링 결과>>> ['강남에스점', '서울시 서초구 서초 1306-3호  ', '02-593-5095']
# ['강남에스점', '서울시 서초구 서초 1306-3호  ', '02-593-5095']
# length>>  4
# =========12===========
# 1--- [<h2>청담에스점</h2>]
# 2--- 청담에스점
# 3--- [<td>평일 07:00~22:00ㅣ토요일 08:00~22:00ㅣ일,공휴일 08:00~21:00</td>, <td>건물지하 주차가능(5,000원 이상 구매시 30분 무료지급/10,000원 이상 구매시 1시간/15,000원 이상 구매시 1시간 30분)</td>, <td>서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호  <!--span class="lot">(서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호)</span--></td>, <td>02-548-6052</td>]
# 4--- 서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호
# 5--- 02-548-6052
# 크롤링 결과>>> ['청담에스점', '서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호  ', '02-548-6052']
# ['청담에스점', '서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호  ', '02-548-6052']
# length>>  5
# =========13===========
# 1--- [<h2>신사점</h2>]
# 2--- 신사점
# 3--- [<td>평일 07:00~22:00ㅣ토요일 09:00~22:00ㅣ일,공휴일 09:00~22:00</td>, <td>주차불가<br/></td>, <td>서울시 강남구 도산대로 126  <!--span class="lot">(서울시 강남구 도산대로 126)</span--></td>, <td>02-548-2741</td>]
# 4--- 서울시 강남구 도산대로 126
# 5--- 02-548-2741
# 크롤링 결과>>> ['신사점', '서울시 강남구 도산대로 126  ', '02-548-2741']
# ['신사점', '서울시 강남구 도산대로 126  ', '02-548-2741']
# length>>  6
# =========14===========
# 1--- [<h2>압구정역점</h2>]
# 2--- 압구정역점
# 3--- [<td>평일 07:00~21:00ㅣ토요일 07:30~21:00ㅣ일,공휴일 07:30~21:00</td>, <td>무료1시간주차가능-건물지하3층,4층</td>, <td>서울시 강남구 논현로 842 압구정빌딩1층  <!--span class="lot">(서울시 강남구 논현로 842 압구정빌딩1층)</span--></td>, <td>02-544-6823</td>]
# 4--- 서울시 강남구 논현로 842 압구정빌딩1층
# 5--- 02-544-6823
# 크롤링 결과>>> ['압구정역점', '서울시 강남구 논현로 842 압구정빌딩1층  ', '02-544-6823']
# ['압구정역점', '서울시 강남구 논현로 842 압구정빌딩1층  ', '02-544-6823']
# length>>  7
# =========15===========
# 1--- [<h2>역삼점</h2>]
# 2--- 역삼점
# 3--- [<td>월-금 07:00-22:00 | 토요일 09:00~22:00ㅣ일.공휴일 09:00-22:00</td>, <td>무료주차불가</td>, <td>서울시 강남구 논현로 512  지상1,2층  <!--span class="lot">(서울시 강남구 논현로 512  지상1,2층)</span--></td>, <td>02-569-8051</td>]
# 4--- 서울시 강남구 논현로 512  지상1,2층
# 5--- 02-569-8051
# 크롤링 결과>>> ['역삼점', '서울시 강남구 논현로 512  지상1,2층  ', '02-569-8051']
# ['역삼점', '서울시 강남구 논현로 512  지상1,2층  ', '02-569-8051']
# length>>  8
# =========16===========
# 1--- [<h2>양재스포타임점</h2>]
# 2--- 양재스포타임점
# 3--- [<td>월-금 06:30~22:00 | 토 7:00~ 22:00  | 일, 공휴일 07:00~21:00</td>, <td>1만원이상구매시 30분무료주차가능(주차권증정)</td>, <td>서울시 서초구 강남대로 213 24호 지하1층  <!--span class="lot">(서울시 서초구 강남대로 213 24호 지하1층)</span--></td>, <td>02-578-6833</td>]
# 4--- 서울시 서초구 강남대로 213 24호 지하1층
# 5--- 02-578-6833
# 크롤링 결과>>> ['양재스포타임점', '서울시 서초구 강남대로 213 24호 지하1층  ', '02-578-6833']
# ['양재스포타임점', '서울시 서초구 강남대로 213 24호 지하1층  ', '02-578-6833']
# length>>  9
# =========17===========
# 1--- [<h2>청담성당점</h2>]
# 2--- 청담성당점
# 3--- [<td>평일 07:00~21:00ㅣ토요일 07:30~21:00ㅣ일,공휴일 07:30~21:00</td>, <td>주차가능 (발렛파킹 : 19:00까지) / 2000원/한 시간 당 추가금액 1000원</td>, <td>서울시 강남구 삼성로 716 LEE76빌딩2층  <!--span class="lot">(서울시 강남구 삼성로 716 LEE76빌딩2층)</span--></td>, <td>02-542-2053</td>]
# 4--- 서울시 강남구 삼성로 716 LEE76빌딩2층
# 5--- 02-542-2053
# 크롤링 결과>>> ['청담성당점', '서울시 강남구 삼성로 716 LEE76빌딩2층  ', '02-542-2053']
# ['청담성당점', '서울시 강남구 삼성로 716 LEE76빌딩2층  ', '02-542-2053']
# length>>  10
# =========18===========
# 1--- [<h2>영동점</h2>]
# 2--- 영동점
# 3--- [<td>월-금 07:00~22:00 | 토요일 08:00~22:00 | 일/공휴일 09:00~22:00 </td>, <td>주차불가</td>, <td>서울 서초구 반포동 736-17 P빌딩 2층  <!--span class="lot">(서울 서초구 반포동 736-17 P빌딩 2층)</span--></td>, <td>02-3443-2096</td>]
# 4--- 서울 서초구 반포동 736-17 P빌딩 2층
# 5--- 02-3443-2096
# 크롤링 결과>>> ['영동점', '서울 서초구 반포동 736-17 P빌딩 2층  ', '02-3443-2096']
# ['영동점', '서울 서초구 반포동 736-17 P빌딩 2층  ', '02-3443-2096']
# length>>  11
# =========19===========
# 1--- [<h2>도곡점</h2>]
# 2--- 도곡점
# 3--- [<td>월~금 06:30~22:00 |토,일, 공휴일 06:30~22:00</td>, <td>1시간30분 무료주차가능(시간초과시,10분당500원)/건물지하주차장</td>, <td>서울시 강남구 언주로 30길 10,112 현대비젼21 112호  <!--span class="lot">(서울시 강남구 언주로 30길 10,112 현대비젼21 112호)</span--></td>, <td>02-572-2781</td>]
# 4--- 서울시 강남구 언주로 30길 10,112 현대비젼21 112호
# 5--- 02-572-2781
# 크롤링 결과>>> ['도곡점', '서울시 강남구 언주로 30길 10,112 현대비젼21 112호  ', '02-572-2781']
# ['도곡점', '서울시 강남구 언주로 30길 10,112 현대비젼21 112호  ', '02-572-2781']
# length>>  12

# %%
result2
# Out:
# [['학동역 DT점', '서울시 강남구 학동로 211 1층  ', '02-3444-9973'],
#  ['차병원점', '서울시 강남구 논현로 566 강남차병원1층  ', '02-538-7615'],
#  ['강남대로점', '서울시 서초구 강남대로 369 1층  ', '02-588-5778'],
#  ['강남에스점', '서울시 서초구 서초 1306-3호  ', '02-593-5095'],
#  ['청담에스점', '서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호  ', '02-548-6052'],
#  ['신사점', '서울시 강남구 도산대로 126  ', '02-548-2741'],
#  ['압구정역점', '서울시 강남구 논현로 842 압구정빌딩1층  ', '02-544-6823'],
#  ['역삼점', '서울시 강남구 논현로 512  지상1,2층  ', '02-569-8051'],
#  ['양재스포타임점', '서울시 서초구 강남대로 213 24호 지하1층  ', '02-578-6833'],
#  ['청담성당점', '서울시 강남구 삼성로 716 LEE76빌딩2층  ', '02-542-2053'],
#  ['영동점', '서울 서초구 반포동 736-17 P빌딩 2층  ', '02-3443-2096'],
#  ['도곡점', '서울시 강남구 언주로 30길 10,112 현대비젼21 112호  ', '02-572-2781']]

# %%
CB_tbl = pd.DataFrame(result2, 
                      columns=('store', 'address','phone'))
CB_tbl.to_csv('../csv-data/CoffeeBean.csv', 
                  encoding='cp949', mode='w', index=True)

# %%
df = pd.read_csv('../csv-data/CoffeeBean.csv', 
                  encoding='cp949')
df
# Out:
#     Unnamed: 0    store                               address         phone
# 0            0  학동역 DT점                  서울시 강남구 학동로 211 1층    02-3444-9973
# 1            1     차병원점             서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 2            2    강남대로점                 서울시 서초구 강남대로 369 1층     02-588-5778
# 3            3    강남에스점                  서울시 서초구 서초 1306-3호     02-593-5095
# 4            4    청담에스점   서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호     02-548-6052
# 5            5      신사점                    서울시 강남구 도산대로 126     02-548-2741
# 6            6    압구정역점             서울시 강남구 논현로 842 압구정빌딩1층     02-544-6823
# 7            7      역삼점             서울시 강남구 논현로 512  지상1,2층     02-569-8051
# 8            8  양재스포타임점           서울시 서초구 강남대로 213 24호 지하1층     02-578-6833
# 9            9    청담성당점           서울시 강남구 삼성로 716 LEE76빌딩2층     02-542-2053
# 10          10      영동점            서울 서초구 반포동 736-17 P빌딩 2층    02-3443-2096
# 11          11      도곡점  서울시 강남구 언주로 30길 10,112 현대비젼21 112호     02-572-2781

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#       store                               address         phone
# 0   학동역 DT점                  서울시 강남구 학동로 211 1층    02-3444-9973
# 1      차병원점             서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 2     강남대로점                 서울시 서초구 강남대로 369 1층     02-588-5778
# 3     강남에스점                  서울시 서초구 서초 1306-3호     02-593-5095
# 4     청담에스점   서울시 강남구 압구정로 461 네이처포엠빌딩B108,109호     02-548-6052
# 5       신사점                    서울시 강남구 도산대로 126     02-548-2741
# 6     압구정역점             서울시 강남구 논현로 842 압구정빌딩1층     02-544-6823
# 7       역삼점             서울시 강남구 논현로 512  지상1,2층     02-569-8051
# 8   양재스포타임점           서울시 서초구 강남대로 213 24호 지하1층     02-578-6833
# 9     청담성당점           서울시 강남구 삼성로 716 LEE76빌딩2층     02-542-2053
# 10      영동점            서울 서초구 반포동 736-17 P빌딩 2층    02-3443-2096
# 11      도곡점  서울시 강남구 언주로 30길 10,112 현대비젼21 112호     02-572-2781
