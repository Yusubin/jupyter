# %%
#함수로 바꾸기 
#url 을 받아 .... 반응 받아오기
def call (url):
    from urllib import request
    from bs4 import BeautifulSoup
    con =request.urlopen(url)
    con 
    print(con.status )#status code)
    doc = BeautifulSoup(con,'html.parser')
    return doc

def confirm_text (rlist, returnlist):
    returnlist=[]
    for i in range(0, len(rlist), 1):
        a= rlist[i].text
        aa =a.replace(',',' ')
        returnlist.append(aa)
    return returnlist

def img_source(rlist, returnlist):
    returnlist=[]
    for i in range(0, len(rlist), 1):
        a= rlist[i].get('src')
        returnlist.append(a)
    return returnlist

# %%
doc=call('https://novel.naver.com/webnovel/ranking')
# Out:
# 200

# %%
free_title=doc.select( 'div.ranking_lst > div.ranking_wrap_left span.tit' )
title=confirm_text(free_title, free_title_list)
title
# Out:
# ['파란집 막내아들',
#  '골동품집 아들',
#  '본업천재 톱매니저',
#  '프로페서',
#  '재벌 설계자',
#  '신이 내린 탑스타',
#  '기억을 읽는 보험조사관',
#  '커피 뽑고 레벨 업!',
#  '카피 헌터 도형석',
#  '에이스 히어로',
#  '좀비묵시록 82-08',
#  'FFF급 건물주',
#  '신의 메스',
#  '갬블링 1945',
#  '리턴 투 플레이어',
#  '치트 쓰는 아이돌',
#  '신과 함께 요리천재',
#  '나 홀로 지배자',
#  '권좌',
#  '너의 옷이 보여',
#  '내가 성공할 확률 100%',
#  '리빌더  두 번의 후회는 없다',
#  '연예계 엑스트라',
#  '재벌집 망나니',
#  '태릉좀비촌',
#  '언더그라운드 피셔맨 클럽',
#  '표류전쟁',
#  '마신전설',
#  '갓 오브 하이스쿨 - 이클립스',
#  '내 안에 축신강림',
#  '장의사라는 직업에 관하여',
#  '야만의 지구',
#  '구해줘',
#  '렛츠',
#  '3cm 헌터',
#  '계와 과학자',
#  '갓 셰프',
#  '언어영역 완전정복',
#  '지니어스 라이프',
#  '진혼']

# %%
free_img=doc.select( '#content > div > div.ranking_lst > div.ranking_wrap_left > ul > li> a > div.pic > img ' )
img=img_source(free_img, free_img_list)
img
# Out:
# ['https://novel-phinf.pstatic.net/20211028_49/novel_1635427169904XbmKR_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201127_285/novel_16064716791154uM1X_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210630_125/novel_16250477780314Wj00_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20220307_234/novel_16466178896305BTCn_JPEG/320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20201229_271/novel_1609236722552stztK_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20211028_134/novel_1635426021816ikmaI_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20211129_256/novel_1638176179068oNhuS_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210930_203/novel_16329838131465v6pG_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20220225_258/novel_1645788742409FwOvF_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210729_17/novel_1627551026317ol1dt_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210825_105/novel_1629889824051mAj4T_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20211129_245/novel_1638176512949Wplfp_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210525_16/novel_1621905150456XncGJ_JPEG/thumbnail_%2B320_320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190821_146/novel_1566358829828Ba8cY_JPEG/_320320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200630_262/novel_1593512790995o1o8j_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210930_254/novel_1632983424336r8pB9_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210825_162/novel_1629888728174Vc3BW_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210428_145/novel_1619587689837bnW3S_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20210729_203/novel_16275511792561GnK6_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190426_125/novel_1556270756333lIvKq_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200731_282/novel_15961617781615mdSn_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190527_197/novel_1558955275870efXbb_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190830_230/novel_1567147260890HfEeS_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20191129_253/novel_15750237260835d2qD_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20170331_65/novel_1490954963910bpX8Q_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_177/novel_1436783391582qGCKH_JPEG/50530.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150720_167/novel_1437385820197YUaTk_JPEG/ED919CEBA598ECA084EC9F81.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150720_235/novel_1437384965335BiLFL_JPEG/EBA788EC8BA0ECA084EC84A4.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150720_160/novel_1437382035023jCcIP_JPEG/EAB093EC98A4ED9598EC99B8ECA084.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200831_40/novel_1598873530759YIbJC_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_137/novel_1436783986988t8Wek_JPEG/73175.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20151127_108/novel_14486081727710Jicw_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_105/novel_1436785033009Ber1h_JPEG/113895.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_297/novel_1436782977614bjCMP_JPEG/13.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20190927_22/novel_1569571574415kLfBW_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_232/novel_1436788202737s2QHO_JPEG/291783.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200925_45/novel_1601019331528guqt5_JPEG/320%2B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20150713_281/novel_1436787829873w3Goj_JPEG/252942.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20200528_183/novel_1590663173521zsKEw_JPEG/3202B320.jpg?type=f150_118_2',
#  'https://novel-phinf.pstatic.net/20170728_246/novel_15012259018372sVum_JPEG/320%2B320.jpg?type=f150_118_2']

# %%
free_star=doc.select('div.ranking_wrap_left span.score_area' )
star=confirm_text(free_star, free_star_list)
for i in range(0, len(star), 1):
    a = free_star[i].text.replace('별점','')
    free_star_list.append(a)
    
star=free_star_list
# Out:
# ['10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.7',
#  '9.7',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.8',
#  '9.9',
#  '7.9',
#  '6.6',
#  '9.9',
#  '7.7',
#  '9.9',
#  '9.8',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '9.8',
#  '9.9',
#  '9.4',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '8.6',
#  '10.0',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.1',
#  '9.9',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.9',
#  '9.9',
#  '10.0',
#  '9.9',
#  '10.0',
#  '9.8',
#  '9.8',
#  '9.9',
#  '9.6',
#  '9.6',
#  '9.9',
#  '10.0',
#  '10.0',
#  '9.8',
#  '9.9',
#  '9.9',
#  '9.8',
#  '9.6',
#  '10.0',
#  '10.0',
#  '9.8',
#  '9.8',
#  '9.8',
#  '8.6',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.8',
#  '9.6',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.9',
#  '9.7',
#  '8.3',
#  '9.9',
#  '9.5',
#  '9.9',
#  '10.0']

# %%
free_author=doc.select('div.ranking_wrap_left   span.author')
author=confirm_text (free_author, free_author_list)
# Out:
# ['왕십리글쟁이',
#  '연주완',
#  '리안하르트',
#  '김연우',
#  '서재현',
#  '동전파스',
#  '공대',
#  '금생',
#  '이락',
#  '원랑',
#  '박스오피스',
#  '켠우',
#  '13월생',
#  '박스오피스',
#  '인덱스',
#  '미카엘K',
#  '천종원',
#  '강판',
#  '날아오르기',
#  '킹묵',
#  '리미트',
#  '서재현',
#  '왕십리글쟁이',
#  '대성당',
#  '임태운',
#  '이상혁',
#  '서하',
#  '김강현',
#  '블로D',
#  '강로이',
#  '나락',
#  '실탄',
#  '김주희',
#  '나민채',
#  '제이로빈',
#  '셜록 F.',
#  '재미핥기',
#  '강양',
#  '잔영',
#  '차우렌즈']

# %%
novel_file1 =open('naver_webnovel_free_prac.csv','w')
novel_file1 .write("img,title,author,star"+"\n")

for i in range(0,len (img),1):
    data=img[i]+","+title[i]+","+author[i]+","+star[i]+"\n"
    novel_file1.write(data)
    
novel_file1.close()

# %%
import pandas as pd

novel = pd.read_csv('naver_webnovel_free_prac.csv', encoding='euc-kr')
novel
# Out:
#                                                   img             title  \
# 0   https://novel-phinf.pstatic.net/20211028_49/no...          파란집 막내아들
# 1   https://novel-phinf.pstatic.net/20201127_285/n...           골동품집 아들
# 2   https://novel-phinf.pstatic.net/20210630_125/n...         본업천재 톱매니저
# 3   https://novel-phinf.pstatic.net/20220307_234/n...              프로페서
# 4   https://novel-phinf.pstatic.net/20201229_271/n...            재벌 설계자
# 5   https://novel-phinf.pstatic.net/20211028_134/n...         신이 내린 탑스타
# 6   https://novel-phinf.pstatic.net/20211129_256/n...      기억을 읽는 보험조사관
# 7   https://novel-phinf.pstatic.net/20210930_203/n...       커피 뽑고 레벨 업!
# 8   https://novel-phinf.pstatic.net/20220225_258/n...         카피 헌터 도형석
# 9   https://novel-phinf.pstatic.net/20210729_17/no...           에이스 히어로
# 10  https://novel-phinf.pstatic.net/20210825_105/n...       좀비묵시록 82-08
# 11  https://novel-phinf.pstatic.net/20211129_245/n...          FFF급 건물주
# 12  https://novel-phinf.pstatic.net/20210525_16/no...             신의 메스
# 13  https://novel-phinf.pstatic.net/20190821_146/n...          갬블링 1945
# 14  https://novel-phinf.pstatic.net/20200630_262/n...         리턴 투 플레이어
# 15  https://novel-phinf.pstatic.net/20210930_254/n...         치트 쓰는 아이돌
# 16  https://novel-phinf.pstatic.net/20210825_162/n...        신과 함께 요리천재
# 17  https://novel-phinf.pstatic.net/20210428_145/n...          나 홀로 지배자
# 18  https://novel-phinf.pstatic.net/20210729_203/n...                권좌
# 19  https://novel-phinf.pstatic.net/20190426_125/n...          너의 옷이 보여
# 20  https://novel-phinf.pstatic.net/20200731_282/n...    내가 성공할 확률 100%
# 21  https://novel-phinf.pstatic.net/20190527_197/n...  리빌더  두 번의 후회는 없다
# 22  https://novel-phinf.pstatic.net/20190830_230/n...          연예계 엑스트라
# 23  https://novel-phinf.pstatic.net/20191129_253/n...           재벌집 망나니
# 24  https://novel-phinf.pstatic.net/20170331_65/no...             태릉좀비촌
# 25  https://novel-phinf.pstatic.net/20150713_177/n...     언더그라운드 피셔맨 클럽
# 26  https://novel-phinf.pstatic.net/20150720_167/n...              표류전쟁
# 27  https://novel-phinf.pstatic.net/20150720_235/n...              마신전설
# 28  https://novel-phinf.pstatic.net/20150720_160/n...  갓 오브 하이스쿨 - 이클립스
# 29  https://novel-phinf.pstatic.net/20200831_40/no...         내 안에 축신강림
# 30  https://novel-phinf.pstatic.net/20150713_137/n...     장의사라는 직업에 관하여
# 31  https://novel-phinf.pstatic.net/20151127_108/n...            야만의 지구
# 32  https://novel-phinf.pstatic.net/20150713_105/n...               구해줘
# 33  https://novel-phinf.pstatic.net/20150713_297/n...                렛츠
# 34  https://novel-phinf.pstatic.net/20190927_22/no...            3cm 헌터
# 35  https://novel-phinf.pstatic.net/20150713_232/n...            계와 과학자
# 36  https://novel-phinf.pstatic.net/20200925_45/no...              갓 셰프
# 37  https://novel-phinf.pstatic.net/20150713_281/n...         언어영역 완전정복
# 38  https://novel-phinf.pstatic.net/20200528_183/n...          지니어스 라이프
# 39  https://novel-phinf.pstatic.net/20170728_246/n...                진혼
#
#     author  star
# 0   왕십리글쟁이  10.0
# 1      연주완   9.7
# 2    리안하르트   9.7
# 3      김연우   9.9
# 4      서재현   9.8
# 5     동전파스   9.6
# 6       공대   9.8
# 7       금생   9.9
# 8       이락   7.9
# 9       원랑   6.6
# 10   박스오피스   9.9
# 11      켠우   7.7
# 12    13월생   9.9
# 13   박스오피스   9.8
# 14     인덱스  10.0
# 15    미카엘K  10.0
# 16     천종원   9.9
# 17      강판   9.9
# 18   날아오르기   9.9
# 19      킹묵   9.7
# 20     리미트   9.8
# 21     서재현   9.9
# 22  왕십리글쟁이   9.4
# 23     대성당   9.9
# 24     임태운   9.9
# 25     이상혁   9.9
# 26      서하   9.9
# 27     김강현   8.6
# 28     블로D  10.0
# 29     강로이  10.0
# 30      나락   9.9
# 31      실탄   9.9
# 32     김주희  10.0
# 33     나민채   9.1
# 34    제이로빈   9.9
# 35   셜록 F.   9.8
# 36    재미핥기   9.9
# 37      강양   9.9
# 38      잔영   9.9
# 39    차우렌즈   9.0
