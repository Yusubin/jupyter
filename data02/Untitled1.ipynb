# %%
import matplotlib

print(matplotlib.__version__)

#! pip install matplotlib = 버젼
# Out:
# 3.1.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2,3,4,5,6])
ypoints=np.array([30,50,70,20,20,70])
y=[]

import random
for i in range(1,7,1):
    y.append(random.randint(1,100))
xpoints1=np.array(x)
ypoints1=np.array(y)
line2=plt.plot(xpoints,ypoints1,marker='^', linestyle='dotted')#산점도> 점으로 그려줌
line1= plt.plot(xpoints,ypoints, marker='*', linestyle='dotted')#직선그래프
plt.ylabel('count')
plt.xlabel('numbers of students')
plt.legend(['term1','term2'])
plt.show()

# %%
xpoints=np.array([1,2,3,4,5,6])
ypoints=np.array([30,50,70,20,20,70])

plt.scatter(xpoints,ypoints)#산점도> 점으로 그려줌

plt.show()

# %%
import random
x=[]
y=[]

for i in range(1,102,1):
    x.append(i)
    y.append(random.randint(1,100))
xpoints1=np.array(x)
ypoints1=np.array(y)
plt.plot(xpoints1,ypoints1)#산점도> 점으로 그려줌
plt.show()

# plt.plot(x,y)#직선그래프
# plt.show()
