# %%
 # %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm

fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '../NanumSquareRoundEB.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
df=pd.read_csv("../csv-data/중소벤처기업진흥공단_내일채움공제 가입자 대상 온라인 유통 상품 선호도 설문조사 결과_20211013.csv", encoding='euc-kr')
df
# Out:
#      성별  연령대    거주지             귀하의 취미는 무엇입니까 어떤 종류위 여행을 좋아하십니까  \
# 0    남성  30대    경기도  독서 / 여행 / 음악/영화감상 / 모임활동         국내여행(휴양지)
# 1    남성  30대  대전광역시                   독서 / 운동         국내여행(휴양지)
# 2    여성  30대  부산광역시              여행 / 음악/영화감상              해외여행
# 3    남성  20대    경기도              여행 / 음악/영화감상         국내여행(휴양지)
# 4    여성  20대  광주광역시         독서 / 운동 / 음악/영화감상         국내여행(휴양지)
# ..   ..  ...    ...                       ...               ...
# 577  여성  20대  서울특별시         운동 / 여행 / 음악/영화감상              해외여행
# 578  여성  20대  인천광역시  운동 / 여행 / 음악/영화감상 / 모임활동              해외여행
# 579  여성  20대   충청북도                   독서 / 운동         국내여행(휴양지)
# 580  여성  20대    경기도              여행 / 음악/영화감상              해외여행
# 581  여성  20대  울산광역시       여행 / 음악/영화감상 / 모임활동         국내여행(휴양지)
#
#     국내여행 희망시 어떤 형태를 선호하십니까 선호하는 여행방식은 어떤 것입니까  \
# 0                     맛집탐방        지인과 함께하는 여행
# 1              맛집탐방 / 역사탐방               가족여행
# 2       맛집탐방 / 역사탐방 / 호텔투어        지인과 함께하는 여행
# 3              맛집탐방 / 호텔투어        지인과 함께하는 여행
# 4              호텔투어 / 캠핑여행        지인과 함께하는 여행
# ..                     ...                ...
# 577     맛집탐방 / 호텔투어 / 캠핑여행               가족여행
# 578            맛집탐방 / 호텔투어        지인과 함께하는 여행
# 579                   맛집탐방        지인과 함께하는 여행
# 580            맛집탐방 / 호텔투어        지인과 함께하는 여행
# 581     맛집탐방 / 호텔투어 / 캠핑여행        지인과 함께하는 여행
#
#                                선호하는 상품 및 서비스 항목은 무엇입니까  \
# 0                    여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연)
# 1                    여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연)
# 2    여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
# 3    여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
# 4    여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
# ..                                                 ...
# 577  여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
# 578  온라인 SHOP(쇼핑, 아울렛) / 생활보장(모바일상품권, 이사, 홈케어) / 자기...
# 579                  여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연)
# 580  여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
# 581  여행(국내외 숙박, 여행상품) / 문화(영화, 도서, 공연) / 온라인 SHOP(쇼...
#
#     온라인 쇼핑을 통해 자주 구매하는 상품 및 서비스는 무엇입니까           가장관심있는 온라인 상품 카테고리는 무엇입니까  \
# 0                          전자제품 / 운동용품                                건강관리
# 1                          전자제품 / 운동용품                             여행 / 문화
# 2                     도서 / 패션/잡화 / 식료품  여행 / 문화 / 생활보장 / 자기계발 / 건강관리 / 식료품
# 3                           전자제품 / 식료품                       여행 / 문화 / 식료품
# 4                   전자제품 / 패션/잡화 / 식료품                            여행 / 식료품
# ..                                 ...                                 ...
# 577                        패션/잡화 / 식료품                            여행 / 식료품
# 578                  전자제품 / 패션/잡화 / 기타                         생활보장 / 자기계발
# 579                                식료품                                자기계발
# 580                       전자제품 / 패션/잡화                      여행 / 문화 / 자기계발
# 581                        패션/잡화 / 식료품  여행 / 문화 / 생활보장 / 자기계발 / 건강관리 / 식료품
#
#                           온라인 쇼핑몰에서 진행했으면하는 이벤트가 무엇입니까
# 0                                     특정 상품 최저가 할인 이벤트
# 1                           여행상품 이용자 대상 적립금(또는 기념품) 지급
# 2                                     특정 상품 최저가 할인 이벤트
# 3    여행상품 이용자 대상 적립금(또는 기념품) 지급 / 특정 상품 최저가 할인 이벤트 ...
# 4    여행상품 이용자 대상 적립금(또는 기념품) 지급 / 구매액에 따른 적립금 지급(또는...
# ..                                                 ...
# 577  여행상품 이용자 대상 적립금(또는 기념품) 지급 / 특정 상품 최저가 할인 이벤트 ...
# 578  특정 상품 최저가 할인 이벤트 / 구매액에 따른 적립금 지급(또는 기념품) 이벤트 ...
# 579      여행상품 이용자 대상 적립금(또는 기념품) 지급 / 특정 상품 최저가 할인 이벤트
# 580      특정 상품 최저가 할인 이벤트 / 구매액에 따른 적립금 지급(또는 기념품) 이벤트
# 581      여행상품 이용자 대상 적립금(또는 기념품) 지급 / 특정 상품 최저가 할인 이벤트
#
# [582 rows x 11 columns]
