# %%
import folium

# %%
#화면에 지도를 띄우자

# %%
#마커를 찍어보자

# %%
#서클을 그려보자.
map = folium.Map(location=[37.57,126.98], 
                 tiles='Stamen Toner',
                 zoom_start=13, )
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#서클을 그려보자.
map = folium.Map(location=[37.57,126.98], 
                 tiles='Stamen Toner',
                 zoom_start=20 )
folium.Marker([37.57, 126.98], popup='여기는 종각역!', icon=folium.Icon(color='red', icon='info-sign')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import json

# %%
geo_path="./skorea_municipalities_geo_simple.json"

# %%
geo_str=json.load(open(geo_path, encoding='utf-8'))
# geo_str

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Library/Fonts/AppleGothic.ttf"
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
import pandas as pd
df=pd.read_csv("folium-data.csv", encoding='utf8')
df.head()
# Out:
#    no  자치구   소상공인    소기업   중기업  대기업        lat         lng
# 0   1  종로구  32778  36715  1202  107  37.575558  126.984867
# 1   2   중구  53454  58527  1919  254  37.509435  127.066958
# 2   3  용산구  15898  18356  1140   49  37.538710  126.965918
# 3   4  성동구  20893  24563  1348   27  37.561731  127.036381
# 4   5  광진구  19943  22785   660   13  37.542873  127.083821

# %%
del df['no']

# %%
df= df.set_index('자치구')

# %%
#서클을 그려보자.
map = folium.Map(location=[37.57,126.98], 
#                  tiles='Stamen Toner',
                 zoom_start=13)

map.choropleth(geo_data=geo_str, data=df['대기업'], columns=[df.index,df['대기업']], fill_color='PuRd', key_on="feature.id")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 중기업, 소기업
map = folium.Map(location=[37.57, 126.98], 
                zoom_start=10
                )
map.choropleth(geo_data=geo_str,
                      data= df['대기업'],
                      columns=[df.index, df['대기업']],
                      fill_color='PuRd',
                      key_on='feature.id'
              )


for n in df.index:
    folium.CircleMarker([df['lat'][n], df['lng'][n]], 
                        radius = df['대기업'][n]*0.1, 
                        color='#3186cc', fill_color='#3186cc', fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
cctv=pd.read_csv('../csv-data/cctv_seoul.csv')
cctv.rename(columns={cctv.columns[0]:'자치구'}, inplace=True)
cctv
# Out:
#      자치구    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
data_result=pd.merge(df, cctv, on='자치구')
# data_result.set_index('자치구')

# %%
police_df=pd.read_excel('../csv-data/seoul_police.xls')
police_df.drop(columns=["경찰청","경찰서","지구대파출소치안센터"], inplace=True)
police_df
# Out:
#       구별  합계
# 0    종로구  25
# 1     중구  20
# 2    용산구  13
# 3    성동구  16
# 4    광진구  13
# 5   동대문구  21
# 6    중랑구  18
# 7    성북구  26
# 8    강북구  15
# 9    도봉구  10
# 10   노원구  17
# 11   은평구  22
# 12  서대문구  12
# 13   마포구  16
# 14   양천구  16
# 15   강서구  13
# 16   구로구  18
# 17   금천구  13
# 18  영등포구  16
# 19   동작구  18
# 20   관악구  20
# 21   서초구  21
# 22   강남구  23
# 23   송파구  22
# 24   강동구  17

# %%
police_df.rename(columns={police_df.columns[0]:'자치구'}, inplace=True)
police_df
# Out:
#      자치구  합계
# 0    종로구  25
# 1     중구  20
# 2    용산구  13
# 3    성동구  16
# 4    광진구  13
# 5   동대문구  21
# 6    중랑구  18
# 7    성북구  26
# 8    강북구  15
# 9    도봉구  10
# 10   노원구  17
# 11   은평구  22
# 12  서대문구  12
# 13   마포구  16
# 14   양천구  16
# 15   강서구  13
# 16   구로구  18
# 17   금천구  13
# 18  영등포구  16
# 19   동작구  18
# 20   관악구  20
# 21   서초구  21
# 22   강남구  23
# 23   송파구  22
# 24   강동구  17

# %%
data_result1=pd.merge(data_result,police_df, on='자치구')
data_result1
# Out:
#      자치구   소상공인    소기업   중기업  대기업        lat         lng    소계  2013년도 이전  \
# 0    종로구  32778  36715  1202  107  37.575558  126.984867  1002        464
# 1     중구  53454  58527  1919  254  37.509435  127.066958   671        413
# 2    용산구  15898  18356  1140   49  37.538710  126.965918  1624       1368
# 3    성동구  20893  24563  1348   27  37.561731  127.036381  1062        730
# 4    광진구  19943  22785   660   13  37.542873  127.083821   707        573
# 5   동대문구  27394  30208   687   16  37.585061  127.045768  1294       1070
# 6    중랑구  24116  26345   365    4  37.618692  127.104714   660        509
# 7    성북구  19886  22062   428    2  37.589748  127.016135  1464       1009
# 8    강북구  15706  17454   287    1  37.637304  127.027340   748        369
# 9    도봉구  15428  16926   247    3  37.653359  127.052682   485        238
# 10   노원구  21561  24212   536    5  37.642524  127.071708  1265        542
# 11   은평구  20589  22601   389    3  37.628360  126.928723  1873       1138
# ...

# %%
data_result1=data_result1.set_index("자치구")

# %%
# 경찰서 개수
map = folium.Map(location=[37.57, 126.98], 
                zoom_start=12
                )
map.choropleth(geo_data=geo_str,
                      data= data_result1['소계'],
                      columns=[df.index, data_result1['소계']],
                      fill_color='PuRd',
                      key_on='feature.id'
              )


for n in df.index:
    folium.CircleMarker([ data_result1['lat'][n], data_result1['lng'][n]], 
                        radius = data_result1['합계'][n]*0.5, 
                        color='#3186cc', fill_color='#3186cc', fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df=pd.read_csv('../csv-data/crime_seoul_2.csv')

df.rename(columns={df.columns[0]:'자치구'}, inplace=True)

# %%
df['절도 발생']=df['절도 발생'].str.replace(',','')
df['절도 검거']=df['절도 검거'].str.replace(',','')
df['폭력 발생']=df['폭력 발생'].str.replace(',','')
df['폭력 검거']=df['폭력 검거'].str.replace(',','')

df['절도 발생'] = pd.to_numeric(df['절도 발생'])
df['절도 검거'] = pd.to_numeric(df['절도 검거'])
df['폭력 발생'] = pd.to_numeric(df['폭력 발생'])
df['폭력 검거'] = pd.to_numeric(df['폭력 검거'])
df.head()
# Out:
#     자치구  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0    중구      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로구      3      3      6      5    115     98   1070    413   1278   1070
# 2    중구      1      0      6      4     65     46   1153    382    869    794
# 3  서대문구      2      2      5      4    154    124   1812    738   2056   1711
# 4   종로구      3      2      5      4     96     63   1114    424   1015    861
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.drop(columns=['Unnamed: 11'], inplace=True)
df['살인 검거율'] = df['살인 검거']/df['살인 발생'] *100
df['강도 검거율'] = df['강도 검거']/df['강도 발생']*100
df['강간 검거율'] = df['강간 검거']/df['강간 발생']*100
df['절도 검거율'] = df['절도 검거']/df['절도 발생']*100
df['폭력 검거율'] = df['절도 검거']/ df['절도 발생']*100

# %%
df['총 범죄 수'] = df['살인 발생']+df['강도 발생']+df['강간 발생']+df['절도 발생']+df['절도 발생']

# %%
df.drop(columns=['강도 검거', '절도 검거', '폭력 검거', '강간 검거','살인 검거' ], inplace=True)

# %%
r_df=df.groupby('자치구').sum()
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 강남구 to 중랑구
# Data columns (total 11 columns):
# 살인 발생     25 non-null int64
# 강도 발생     25 non-null int64
# 강간 발생     25 non-null int64
# 절도 발생     25 non-null int64
# 폭력 발생     25 non-null int64
# 살인 검거율    25 non-null float64
# 강도 검거율    25 non-null float64
# 강간 검거율    25 non-null float64
# 절도 검거율    25 non-null float64
# 폭력 검거율    25 non-null float64
# 총 범죄 수    25 non-null int64
# dtypes: float64(5), int64(6)
# memory usage: 2.3+ KB

# %%
data_result2=pd.merge(data_result1, r_df, on='자치구')
# data_result.set_index('자치구')

# %%
data_result2.index
# Out:
# Index(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구',
#        '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구',
#        '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='자치구')

# %%
# 경찰서 개수
map = folium.Map(location=[37.57, 126.98], 
                zoom_start=12
                )
map.choropleth(geo_data=geo_str,
                      data= data_result2['합계'],
                      columns=[df.index, data_result2['합계']],
                      fill_color='PuRd',
                      key_on='feature.id'
              )


for n in data_result2.index:
    folium.CircleMarker([data_result2['lat'][n], data_result2['lng'][n]], 
                        radius = data_result2['총 범죄 수'][n]*0.009, 
                        color='#B40404', fill_color='#B40404', fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 경찰서 개수
map = folium.Map(location=[37.57, 126.98], 
                zoom_start=12
                )
map.choropleth(geo_data=geo_str,
                      data= data_result1['소계'],
                      columns=[df.index, data_result1['소계']],
                      fill_color='PuRd',
                      key_on='feature.id'
              )


for n in data_result2.index:
    folium.CircleMarker([data_result2['lat'][n], data_result2['lng'][n]], 
                        radius = data_result2['총 범죄 수'][n]*0.009, 
                        color='#B40404', fill_color='#B40404', fill=True).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
