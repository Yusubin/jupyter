# %%
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')
import re
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import rc
import matplotlib.font_manager as fm
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(5)
import matplotlib.pyplot as plt
fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '../NanumSquareRoundEB.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
df=pd.read_csv('cs_data1.csv')
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      594 non-null    object
#  1   분류      595 non-null    object
# dtypes: object(2)
# memory usage: 9.4+ KB

# %%
#라벨인코딩
encoder=LabelEncoder()
df['분류'].unique()
encoder.fit(df['분류'].unique())
target=encoder.transform(df['분류'])

df['분류']= target
df['분류']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 590    3
# 591    3
# 592    3
# 593    3
# 594    3
# Name: 분류, Length: 595, dtype: int32

# %%
df
# Out:
#                                                     제목  분류
# 0                                        해외에서 주문하고 싶어요   0
# 1                                해외배송의 배송 기간은 어떻게 되나요?   0
# 2                                      해외카드 결제가 가능한가요?   0
# 3    ['\nA\n★ 주문시 꼭 기재하실 정보 : 우편번호  영문주소  영문이름  해외 ...   0
# 4    ['\nA\n업체에서 출고이후 넉넉하게 7~15일 정도 안내드리고 있으며  \n지역...   0
# ..                                                 ...  ..
# 590  ['\n\n사뿐 가족이 되시면 다양한 혜택이 있으십니다.\n주문 및 배송 교환 반품...   3
# 591  ['\n\n사뿐은 회원이 아니셔도 주문 가능하십니다.\n상품을 CART(장바구니)에...   3
# 592  ['\n\n아이디를 잊어버렸을경우\n로그인-회원아이디 찾기-이름 이메일 입력-아이디...   3
# 593  ['\n\n전화번호 및 주소등 개인정보 변경을 원하실때는\n상단에 마이페이지-회원정...   3
# 594  ['\n\n회원탈퇴는 로그인 후 마이페이지에서 가능하십니다.\n탈퇴시 현재 보유하고...   3
#
# [595 rows x 2 columns]

# %%
encoder.classes_
# Out:
# array(['배송', '상품관련', '주문', '회원'], dtype=object)

# %%
test_labels = ['배송','주문'] 
print(test_labels, '->', encoder.transform(test_labels))
# Out:
# ['배송', '주문'] -> [0 2]

# %% [markdown]
# 0-> 배송
# 1-> 상품관련
# 2-> 주문
# 3->회원

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      594 non-null    object
#  1   분류      595 non-null    int32
# dtypes: int32(1), object(1)
# memory usage: 7.1+ KB

# %%
df['분류'].value_counts().plot(kind='bar')

# %%
import re#규칙을 가지고 필터링해주는

# %%
df['제목'] = df['제목'].apply(lambda x: re.sub(r'[^ ㄱ-ㅣ가-힣]+', "", str(x)))

#ㄱ-|가-힣 한글이 아닌것은 다 뺴라

# %%
df.head()
# Out:
#                                                   제목  분류
# 0                                      해외에서 주문하고 싶어요   0
# 1                               해외배송의 배송 기간은 어떻게 되나요   0
# 2                                     해외카드 결제가 가능한가요   0
# 3   주문시 꼭 기재하실 정보  우편번호  영문주소  영문이름  해외 연락처 해외배송 ...   0
# 4  업체에서 출고이후 넉넉하게 일 정도 안내드리고 있으며  지역에 따라 소요기간은 다른...   0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Okt

okt = Okt()

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df = 5, max_df = 0.9)
tfidf
# Out:
# TfidfVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2))

# %%
X_train, X_test, y_train, y_test = train_test_split(df['제목'], df['분류'], test_size=0.2, random_state=42)

# %%
X_train.head()
y_train.head()
# Out:
# 211    2
# 426    2
# 519    2
# 137    1
# 593    3
# Name: 분류, dtype: int32

# %%
X_test.head()
# Out:
# 188                           적립금으로 구매시 구매금액의 적립금이 적용되나요
# 238    자동입금확인 프로그램으로 입금확인이 되기 때문에 입금 후 분 정도 시간이 소요되십니...
# 462                                      주문이 자동 취소 되어있어요
# 465    주문 후 일 이내 미입금 시 가상계좌가 무효 처리되어 입금이 불가합니다 예시 일 주...
# 182                                          배송메세지가 뭔가요
# Name: 제목, dtype: object

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 2))

# %%
sorted(tfidf.vocabulary_.items())
# Out:
# [('가격으로', 0),
#  ('가격으로 수입하여', 1),
#  ('가격의', 2),
#  ('가격의 변동에', 3),
#  ('가능', 4),
#  ('가능 만원', 5),
#  ('가능 한도를', 6),
#  ('가능 합니다', 7),
#  ('가능 합니다대한통운', 8),
#  ('가능 회원', 9),
#  ('가능하며', 10),
#  ('가능하지', 11),
#  ('가능하지 않습니다', 12),
#  ('가능하지 않으니', 13),
#  ('가능한', 14),
#  ('가능한 기간은', 15),
#  ('가능한가요', 16),
#  ('가능함', 17),
#  ('가능함 만원', 18),
#  ('가능합니다', 19),
#  ('가능합니다 교환', 20),
#  ('가능합니다 상품은', 21),
#  ('가능합니다 주문', 22),
#  ('가능합니다 품절된', 23),
#  ('가능합니다 해당', 24),
#  ('가능합니다년도', 25),
#  ('가능합니다년도 출생자의', 26),
#  ('가능합니다단', 27),
#  ('가능합니다단 결제', 28),
#  ('가능합니다인터넷', 29),
#  ('가능합니다인터넷 뱅킹', 30),
#  ('가립니다', 31),
#  ('가립니다 해당', 32),
#  ('가상', 33),
#  ('가상 계좌', 34),
#  ('가상계좌', 35),
#  ('가상계좌 주문', 36),
#  ('가상계좌 주문이', 37),
#  ('가상계좌는', 38),
#  ('가상계좌는 고객님께만', 39),
#  ('가상계좌로', 40),
#  ('가상의', 41),
#  ('가상의 인터넷안전결제', 42),
#  ('가입', 43),
#  ('가입 기본', 44),
#  ('가입인증', 45),
#  ('가장', 46),
#  ('가장 정확합니다', 47),
#  ('가지는', 48),
#  ('가지는 것이', 49),
#  ('가지의', 50),
#  ('가지의 결제수단을', 51),
#  ('가치가', 52),
#  ('가치가 현저히', 53),
#  ('가품으로', 54),
#  ('가품으로 판명될', 55),
#  ('각각', 56),
#  ('각각 배송이', 57),
#  ('각각 입금해주셔야', 58),
#  ('감소하는', 59),
#  ('감소하는 경우', 60),
#  ('같은', 61),
#  ('같은 브랜드', 62),
#  ('같은 택배사로', 63),
#  ('같은 확인', 64),
#  ('같이', 65),
#  ('같이 개봉', 66),
#  ('같이 처리합니다', 67),
#  ('개봉', 68),
#  ('개봉 제품의', 69),
#  ('개인', 70),
#  ('개인 정보', 71),
#  ('개인정보', 72),
#  ('개인정보 제공', 73),
#  ('거래', 74),
#  ('거래 명예훼손', 75),
#  ('거래 은행에', 76),
#  ('거슬러', 77),
#  ('거슬러 받거나', 78),
#  ('거쳐', 79),
#  ('거쳐 진위', 80),
#  ('건물명이', 81),
#  ('건물명이 검색되지', 82),
#  ('건물명이 변경되어', 83),
#  ('건물에', 84),
#  ('건물에 부여되는', 85),
#  ('건물이', 86),
#  ('건물이 있지', 87),
#  ('검색되는', 88),
#  ('검색되는 주소를', 89),
#  ('검색되지', 90),
#  ('검색되지 않을', 91),
#  ('검색을', 92),
#  ('검색을 통해', 93),
#  ('검색이', 94),
#  ('검색이 안될', 95),
#  ('검수', 96),
#  ('검수 기간은', 97),
#  ('검수 진행', 98),
#  ('검증을', 99),
#  ('검증을 거쳐', 100),
#  ('것으로', 101),
#  ('것으로 국민우리신한카드로', 102),
#  ('것으로 등이', 103),
#  ('것이', 104),
#  ('것이 가장', 105),
#  ('것이 특징이며', 106),
#  ('게시판', 107),
#  ('게시판에', 108),
#  ('게시판에 게재합니다', 109),
#  ('게시판을', 110),
#  ('게시판을 통하여', 111),
#  ('게시판이나', 112),
#  ('게시판이나 입점', 113),
#  ('게재하도록', 114),
#  ('게재하도록 권고합니다', 115),
#  ('게재합니다', 116),
#  ('게재합니다 또한', 117),
#  ('결제', 118),
#  ('결제 가능', 119),
#  ('결제 가능합니다년도', 120),
#  ('결제 구매금액의', 121),
#  ('결제 금액의', 122),
#  ('결제 금액이', 123),
#  ('결제 대금은', 124),
#  ('결제 대금을', 125),
#  ('결제 비밀번호', 126),
#  ('결제 비밀번호를', 127),
#  ('결제 설정에서', 128),
#  ('결제 수수료를', 129),
#  ('결제 월이', 130),
#  ('결제 추가로', 131),
#  ('결제 현금영수증', 132),
#  ('결제 휴대폰', 133),
#  ('결제가', 134),
#  ('결제금액의', 135),
#  ('결제금액의 차액은', 136),
#  ('결제금액이', 137),
#  ('결제금액이 만원', 138),
#  ('결제는', 139),
#  ('결제는 국민우리신한카드사에서', 140),
#  ('결제를', 141),
#  ('결제를 진행하면', 142),
#  ('결제만', 143),
#  ('결제만 가능합니다', 144),
#  ('결제수단', 145),
#  ('결제수단 선택에서', 146),
#  ('결제수단을', 147),
#  ('결제수단을 이용하시거나', 148),
#  ('결제수단을 이용해', 149),
#  ('결제시', 150),
#  ('결제월', 151),
#  ('결제월 기준', 152),
#  ('결제의', 153),
#  ('결제의 환불', 154),
#  ('결제하는', 155),
#  ('결제하는 방법으로', 156),
#  ('결제한', 157),
#  ('결제할', 158),
#  ('결제할 있습니다아직', 159),
#  ('결제할 카드번호를', 160),
#  ('경동', 161),
#  ('경동 대신', 162),
#  ('경로마이페이지', 163),
#  ('경로마이페이지 배송', 164),
#  ('경로모바일앱웹', 165),
#  ('경로모바일앱웹 마이페이지', 166),
#  ('경로에서', 167),
#  ('경로에서 배송진행', 168),
#  ('경우', 169),
#  ('경우 계좌로', 170),
#  ('경우 교환', 171),
#  ('경우 교환환불이', 172),
#  ('경우 도로명주소', 173),
#  ('경우 만원', 174),
#  ('경우 만원미성년자', 175),
#  ('경우 무신사는', 176),
#  ('경우 문의글로', 177),
#  ('경우 반품비가', 178),
#  ('경우 반품이', 179),
#  ('경우 본사에서', 180),
#  ('경우 브랜드', 181),
#  ('경우 브랜드의', 182),
#  ('경우 생일이', 183),
#  ('경우 영업점을', 184),
#  ('경우 주문', 185),
#  ('경우 평일', 186),
#  ('경우 플러그인', 187),
#  ('경우 한국', 188),
#  ('경우 해당', 189),
#  ('경우 확인해', 190),
#  ('경우 회원님을', 191),
#  ('경우가', 192),
#  ('경우는', 193),
#  ('경우는 인터넷뱅킹에', 194),
#  ('경우에는', 195),
#  ('경우에는 각각', 196),
#  ('경우에만', 197),
#  ('경우에만 주문배송픽업', 198),
#  ('경우원', 199),
#  ('경우원 단위', 200),
#  ('경위', 201),
#  ('경위 처리결과를', 202),
#  ('계약을', 203),
#  ('계약을 맺고', 204),
#  ('계약하여', 205),
#  ('계약하여 한국', 206),
#  ('계좌', 207),
#  ('계좌 결제만', 208),
#  ('계좌로', 209),
#  ('계좌로 환불됩니다', 210),
#  ('계좌번호', 211),
#  ('계좌번호 등의', 212),
#  ('계좌번호 입니다', 213),
#  ('계좌이체', 214),
#  ('계좌이체 기기', 215),
#  ('계좌이체 하셔야', 216),
#  ('계좌정보로', 217),
#  ('계좌정보로 입금자', 218),
#  ('고객님께만', 219),
#  ('고객님께만 발급되는', 220),
#  ('고객님께서', 221),
#  ('고객님들께서는', 222),
#  ('고객님들께서는 가지의', 223),
#  ('고객님의', 224),
#  ('고객님이', 225),
#  ('고객님이 소유하신', 226),
#  ('고객님이 소유한', 227),
#  ('고객별', 228),
#  ('고객별 판매', 229),
#  ('고객센터', 230),
#  ('고객센터 또는', 231),
#  ('고객센터 번호는', 232),
#  ('고객센터로', 233),
#  ('고객센터로 문의', 234),
#  ('고객센터로 문의해', 235),
#  ('곳에서는', 236),
#  ('곳에서는 만나기', 237),
#  ('공개', 238),
#  ('공개 글은', 239),
#  ('공식', 240),
#  ('공식 수입원이', 241),
#  ('공인인증', 242),
#  ('공인인증 과정이', 243),
#  ('공인인증 만원', 244),
#  ('공인인증번호', 245),
#  ('공인인증번호 입력', 246),
#  ('공인인증번호를', 247),
#  ('공인인증번호를 입력하셔야', 248),
#  ('공인인증서가', 249),
#  ('공인인증서가 없으신', 250),
#  ('공인인증서를', 251),
#  ('공인인증서를 다운로드', 252),
#  ('공인인증안심클릭', 253),
#  ('공인인증안심클릭 등록방법', 254),
#  ('공지', 255),
#  ('공지 게시판에', 256),
#  ('공지 판매', 257),
#  ('과정상품', 258),
#  ('과정상품 회수', 259),
#  ('과정은', 260),
#  ('과정은 아래', 261),
#  ('과정이', 262),
#  ('과정이 필수입니다', 263),
#  ('관계', 264),
#  ('관계 확인', 265),
#  ('관련', 266),
#  ('관련 내용은노출이', 267),
#  ('관련 업체에', 268),
#  ('관련 없는', 269),
#  ('관련된', 270),
#  ('관련된 문의', 271),
#  ('광고성', 272),
#  ('광고성 등의', 273),
#  ('광범위하게', 274),
#  ('광범위하게 디자인', 275),
#  ('교체', 276),
#  ('교체 상품', 277),
#  ('교체 상품이', 278),
#  ('교환', 279),
#  ('교환 상품', 280),
#  ('교환 신청이', 281),
#  ('교환 요청', 282),
#  ('교환 요청웹', 283),
#  ('교환 접수', 284),
#  ('교환 진행', 285),
#  ('교환 진행중인', 286),
#  ('교환 환불', 287),
#  ('교환 희망', 288),
#  ('교환반품', 289),
#  ('교환은', 290),
#  ('교환은 배송', 291),
#  ('교환을', 292),
#  ('교환을 선택', 293),
#  ('교환의', 294),
#  ('교환의 경우', 295),
#  ('교환이', 296),
#  ('교환이 가능하지', 297),
#  ('교환이 불가합니다', 298),
#  ('교환처리가', 299),
#  ('교환처리가 어려운', 300),
#  ('교환환불', 301),
#  ('교환환불이', 302),
#  ('교환환불이 가능하지', 303),
#  ('구매', 304),
#  ('구매금액의', 305),
#  ('구매금액의 수수료가', 306),
#  ('구매를', 307),
#  ('구매를 희망하시는', 308),
#  ('구매시', 309),
#  ('구매하신', 310),
#  ('구매하신 상품이', 311),
#  ('구입하셔도', 312),
#  ('구입하셔도 됩니다위와', 313),
#  ('국가', 314),
#  ('국가 판매', 315),
#  ('국민우리신한카드로', 316),
#  ('국민우리신한카드로 결제할', 317),
#  ('국민우리신한카드사에서', 318),
#  ('국민우리신한카드사에서 의무적으로', 319),
#  ('국민우리신한카드안전결제', 320),
#  ('국민우리신한카드안전결제 선택', 321),
#  ('권고합니다', 322),
#  ('권고합니다 무신사', 323),
#  ('그대로', 324),
#  ('그대로 보관', 325),
#  ('그대로 이중으로', 326),
#  ('그대로 포장해서', 327),
#  ('그대로를', 328),
#  ('그대로를 보관', 329),
#  ('글은', 330),
#  ('글은 비밀글로', 331),
#  ('금액', 332),
#  ('금액의', 333),
#  ('금액의 단위까지', 334),
#  ('금액이', 335),
#  ('금액이 포함된', 336),
#  ('금액이 환불', 337),
#  ('기간', 338),
#  ('기간 한정', 339),
#  ('기간 한정의', 340),
#  ('기간은', 341),
#  ('기간은 결제월', 342),
#  ('기간은 평일', 343),
#  ('기간이', 344),
#  ('기간이 연장될', 345),
#  ('기기', 346),
#  ('기기 등록', 347),
#  ('기기 은행', 348),
#  ('기기 이용', 349),
#  ('기반으로', 350),
#  ('기반으로 합니다검색', 351),
#  ('기반으로 합니다띄어쓰기', 352),
#  ('기본', 353),
#  ('기본 혜택', 354),
#  ('기준', 355),
#  ('기준 소요됩니다', 356),
#  ('기준 이내', 357),
#  ('기준 이상', 358),
#  ('기준 익월', 359),
#  ('기준에', 360),
#  ('기준에 따라', 361),
#  ('기준위', 362),
#  ('기준위 한도는', 363),
#  ('기준으로', 364),
#  ('기타', 365),
#  ('까지는', 366),
#  ('까지는 평일', 367),
#  ('남겨주시면', 368),
#  ('남겨주시면브랜드', 369),
#  ('남겨주시면브랜드 담당자가', 370),
#  ('낮은', 371),
#  ('낮은 가격으로', 372),
#  ('내부', 373),
#  ('내부 조사를', 374),
#  ('내역', 375),
#  ('내역 조회', 376),
#  ('내역에서는', 377),
#  ('내역에서는 상품', 378),
#  ('내외부', 379),
#  ('내외부 검증을', 380),
#  ('내용', 381),
#  ('내용 참고해', 382),
#  ('내용은노출이', 383),
#  ('내용은노출이 되지', 384),
#  ('내용을', 385),
#  ('내용을 확인해', 386),
#  ('노출로', 387),
#  ('노출로 인한', 388),
#  ('누락브랜드', 389),
#  ('누락브랜드 상품에', 390),
#  ('누릅니다', 391),
#  ('누릅니다 결제', 392),
#  ('누릅니다 발급', 393),
#  ('다르기', 394),
#  ('다르기 때문에', 395),
#  ('다르더라도', 396),
#  ('다르더라도 입금이', 397),
#  ('다르면', 398),
#  ('다르면 교환이', 399),
#  ('다르므로', 400),
#  ('다르므로 한번에', 401),
#  ('다른', 402),
#  ('다른 결제수단을', 403),
#  ('다른 곳에서는', 404),
#  ('다른 상품으로', 405),
#  ('다를', 406),
#  ('다를 경우', 407),
#  ('다릅니다아래', 408),
#  ('다릅니다아래 내용을', 409),
#  ('다시', 410),
#  ('다운로드', 411),
#  ('다운로드 받아', 412),
#  ('다음', 413),
#  ('다음 단계를', 414),
#  ('다음 휴대폰', 415),
#  ('다음과', 416),
#  ('다음과 같이', 417),
#  ('다음날', 418),
#  ('다음달', 419),
#  ('다음달 일에', 420),
#  ('다음에', 421),
#  ('다음에 등록하기를', 422),
#  ('다하겠습니다', 423),
#  ('단계를', 424),
#  ('단계를 진행합니다', 425),
#  ('단독', 426),
#  ('단독 판매', 427),
#  ('단위', 428),
#  ('단위 입금이', 429),
#  ('단위까지', 430),
#  ('단위까지 맞춰야', 431),
#  ('단위까지 정확히', 432),
#  ('달라도', 433),
#  ('달라도 상품', 434),
#  ('담당자가', 435),
#  ('담당자가 직접', 436),
#  ('답변드립니다', 437),
#  ('답변드립니다 상품과', 438),
#  ('대금은', 439),
#  ('대금은 다음', 440),
#  ('대금을', 441),
#  ('대금을 휴대폰으로', 442),
#  ('대기', 443),
#  ('대기 배송조회', 444),
#  ('대부분', 445),
#  ('대부분 불가합니다', 446),
#  ('대부분입니다', 447),
#  ('대부분입니다 일부', 448),
#  ('대상이', 449),
#  ('대상이 아닙니다', 450),
#  ('대상카드', 451),
#  ('대상카드 삼성외환신한현대롯데하나씨티', 452),
#  ('대신', 453),
#  ('대신 배송', 454),
#  ('대한', 455),
#  ('대한 경위', 456),
#  ('대한통운', 457),
#  ('대해', 458),
#  ('대해 안내드립니다', 459),
#  ('도로명', 460),
#  ('도로명 조회', 461),
#  ('도로명 주소로', 462),
#  ('도로명은', 463),
#  ('도로명은 건물에', 464),
#  ('도로명주소', 465),
#  ('도로명주소 도움센터에', 466),
#  ('도용', 467),
#  ('도용 또는', 468),
#  ('도용 라벨', 469),
#  ('도움센터에', 470),
#  ('도움센터에 등록', 471),
#  ('도움센터에 변경', 472),
#  ('도착', 473),
#  ('도착 검수', 474),
#  ('도착까지', 475),
#  ('도착까지 평일', 476),
#  ('도착하지', 477),
#  ('도착하지 않는', 478),
#  ('동봉됩니다', 479),
#  ('동봉됩니다 정식', 480),
#  ('동의를', 481),
#  ('동의를 체크하여', 482),
#  ('동일하게', 483),
#  ('동일한', 484),
#  ('동일한 상품명의', 485),
#  ('되고', 486),
#  ('되고 상품이', 487),
#  ('되나요', 488),
#  ('되는', 489),
#  ('되는 경우', 490),
#  ('되어', 491),
#  ('되어 있어야', 492),
#  ('되어 있지', 493),
#  ('되지', 494),
#  ('되지 않도록', 495),
#  ('되지 않았다면', 496),
#  ('됩니다', 497),
#  ('됩니다 성인회원의', 498),
#  ('됩니다 주문내역조회에서', 499),
#  ('됩니다 참고사항거래금액이', 500),
#  ('됩니다브랜드가', 501),
#  ('됩니다브랜드가 달라도', 502),
#  ('됩니다위와', 503),
#  ('됩니다위와 같은', 504),
#  ('드리고', 505),
#  ('드립니다', 506),
#  ('드립니다 주문번호마다', 507),
#  ('들어갑니다', 508),
#  ('들어갑니다 결제', 509),
#  ('등급별', 510),
#  ('등급별 차등', 511),
#  ('등급별 추가', 512),
#  ('등급에', 513),
#  ('등급에 따라', 514),
#  ('등록', 515),
#  ('등록 가능', 516),
#  ('등록 가능함', 517),
#  ('등록 가능합니다', 518),
#  ('등록 여부를', 519),
#  ('등록 요청을', 520),
#  ('등록되어', 521),
#  ('등록되어 있으나', 522),
#  ('등록되어 있지', 523),
#  ('등록되지', 524),
#  ('등록되지 않습니다도로명', 525),
#  ('등록방법', 526),
#  ('등록방법 고객님이', 527),
#  ('등록이', 528),
#  ('등록이 되어', 529),
#  ('등록이 불가능합니다', 530),
#  ('등록하기를', 531),
#  ('등록하기를 선택해', 532),
#  ('등을', 533),
#  ('등을 받은', 534),
#  ('등의', 535),
#  ('등의 개인', 536),
#  ('등의 경우', 537),
#  ('등의 문의는', 538),
#  ('등의 제품과', 539),
#  ('등의 책임을', 540),
#  ('등이', 541),
#  ('등이 대부분', 542),
#  ('디자인', 543),
#  ('디자인 도용', 544),
#  ('따라', 545),
#  ('따라 결제', 546),
#  ('따라 의무', 547),
#  ('따라 조금씩', 548),
#  ('따라 처리', 549),
#  ('따라 최고', 550),
#  ('따라 출고지가', 551),
#  ('따라 한정판', 552),
#  ('따라서', 553),
#  ('따라서 주문자와', 554),
#  ('따로', 555),
#  ('따로 배송', 556),
#  ('따른', 557),
#  ('따른 차액을', 558),
#  ('때는', 559),
#  ('때는 공인인증', 560),
#  ('때문에', 561),
#  ('때문에 여러', 562),
#  ('또는', 563),
#  ('또는 가상', 564),
#  ('또는 결제', 565),
#  ('또는 공인인증', 566),
#  ('또는 라벨', 567),
#  ('또는 소명', 568),
#  ('또는 에서도', 569),
#  ('또는 톡톡으로', 570),
#  ('또한', 571),
#  ('또한 업체에게', 572),
#  ('뜨는', 573),
#  ('뜨는 플러그인', 574),
#  ('라벨', 575),
#  ('라벨 교체', 576),
#  ('라벨 제거', 577),
#  ('라인의', 578),
#  ('라인의 특별한', 579),
#  ('로그인', 580),
#  ('로그인정보', 581),
#  ('로젠', 582),
#  ('로젠 우체국', 583),
#  ('로지스', 584),
#  ('로지스 경동', 585),
#  ('롯데', 586),
#  ('롯데 로젠', 587),
#  ('룸페커', 588),
#  ('마이페이지', 589),
#  ('마이페이지 주문', 590),
#  ('마이페이지 주문내역', 591),
#  ('마이페이지 주문배송픽업', 592),
#  ('마이페이지에서', 593),
#  ('만나기', 594),
#  ('만나기 힘든', 595),
#  ('만원', 596),
#  ('만원 만원까지', 597),
#  ('만원 미만', 598),
#  ('만원 이상', 599),
#  ('만원 이상인', 600),
#  ('만원 이상일', 601),
#  ('만원까지', 602),
#  ('만원까지 결제', 603),
#  ('만원미성년자', 604),
#  ('만원미성년자 회원의', 605),
#  ('많은', 606),
#  ('맞춰야', 607),
#  ('맞춰야 입금', 608),
#  ('매월', 609),
#  ('매월 제공', 610),
#  ('맺고', 611),
#  ('맺고 판매되므로', 612),
#  ('명과', 613),
#  ('명과 상관없이', 614),
#  ('명예훼손', 615),
#  ('명예훼손 쇼핑몰', 616),
#  ('모니터', 617),
#  ('모니터 환경에', 618),
#  ('모두', 619),
#  ('모든', 620),
#  ('모든 상품을', 621),
#  ('모든 제품은', 622),
#  ('목록에서', 623),
#  ('목록에서 작성할', 624),
#  ('목적으로', 625),
#  ('목적으로 공식', 626),
#  ('무단도용을', 627),
#  ('무단도용을 방지해주는', 628),
#  ('무료', 629),
#  ('무료 배송', 630),
#  ('무신사', 631),
#  ('무신사 기준에', 632),
#  ('무신사 내외부', 633),
#  ('무신사 단독', 634),
#  ('무신사 스토어', 635),
#  ('무신사 스토어가', 636),
#  ('무신사 스토어에서는', 637),
#  ('무신사 스페셜숍에서는', 638),
#  ('무신사 자동회수', 639),
#  ('무신사 커뮤니티', 640),
#  ('무신사는', 641),
#  ('무신사는 소명', 642),
#  ('무신사는 입점', 643),
#  ('무신사페이', 644),
#  ('무엇인가요', 645),
#  ('무통장', 646),
#  ('무통장 입금을', 647),
#  ('묶음', 648),
#  ('묶음 발송처리는', 649),
#  ('문의', 650),
#  ('문의 목록에서', 651),
#  ('문의 부탁드립니다', 652),
#  ('문의 사항을', 653),
#  ('문의글로', 654),
#  ('문의글로 주소지와', 655),
#  ('문의는', 656),
#  ('문의는 숨김', 657),
#  ('문의로', 658),
#  ('문의로 사진과', 659),
#  ('문의를', 660),
#  ('문의를 통해', 661),
#  ('문의하고자', 662),
#  ('문의하고자 하는', 663),
#  ('문의하시는', 664),
#  ('문의하시는 것이', 665),
#  ('문의해', 666),
#  ('문의해 주세요', 667),
#  ('문의해 주시기', 668),
#  ('문자를', 669),
#  ('문자를 받아보실', 670),
#  ('문자를 캡처', 671),
#  ('문제를', 672),
#  ('문제를 파악합니다', 673),
#  ('미리', 674),
#  ('미리 설정해', 675),
#  ('미만', 676),
#  ('미만 안심클릭', 677),
#  ('믿고', 678),
#  ('믿고 구입하셔도', 679),
#  ('바랍니다', 680),
#  ('바랍니다 공개', 681),
#  ('바랍니다 마이페이지', 682),
#  ('바랍니다 인터넷', 683),
#  ('바랍니다단', 684),
#  ('바랍니다단 도로명은', 685),
#  ('바랍니다도로명', 686),
#  ('바랍니다도로명 조회', 687),
#  ('바랍니다도로명 주소가', 688),
#  ('바랍니다은행에', 689),
#  ('바랍니다은행에 방문하여', 690),
#  ('바로', 691),
#  ('바로 서비스를', 692),
#  ('박스', 693),
#  ('박스 제품', 694),
#  ('박스 훼손', 695),
#  ('반복적이거나', 696),
#  ('반복적이거나 광범위하게', 697),
#  ('반복적인', 698),
#  ('반복적인 주문취소', 699),
#  ('반송장', 700),
#  ('반송장 번호가', 701),
#  ('반송장 정보는', 702),
#  ('반품', 703),
#  ('반품 도착', 704),
#  ('반품 도착까지', 705),
#  ('반품 방법을', 706),
#  ('반품 예약해야', 707),
#  ('반품비가', 708),
#  ('반품비가 발생될', 709),
#  ('반품시', 710),
#  ('반품이', 711),
#  ('반품이 가능하지', 712),
#  ('반품할', 713),
#  ('반품할 상품의', 714),
#  ('반품해', 715),
#  ('반품해 주셔야', 716),
#  ('받거나', 717),
#  ('받거나 통장으로', 718),
#  ('받아', 719),
#  ('받아 설치하시면', 720),
#  ('받아보실', 721),
#  ('받아보실 있습니다', 722),
#  ('받아본', 723),
#  ('받아본 그대로', 724),
#  ('받았는데', 725),
#  ('받았다면', 726),
#  ('받았다면 해당', 727),
#  ('받았던', 728),
#  ('받았던 상태', 729),
#  ('받은', 730),
#  ('받은 상태', 731),
#  ('받은 택배사와', 732),
#  ('받을', 733),
#  ('받을 있습니다타', 734),
#  ('발급', 735),
#  ('발급 설정을', 736),
#  ('발급 종류', 737),
#  ('발급되는', 738),
#  ('발급되는 일회성', 739),
#  ('발급된', 740),
#  ('발급된 계좌정보로', 741),
#  ('발급이', 742),
#  ('발급이 완료', 743),
#  ('발급하는', 744),
#  ('발급하는 가상의', 745),
#  ('발생', 746),
#  ('발생 다음과', 747),
#  ('발생되는', 748),
#  ('발생되는 참고', 749),
#  ('발생될', 750),
#  ('발생될 있고', 751),
#  ('발생하는', 752),
#  ('발생하는 업체는', 753),
#  ('발생합니다', 754),
#  ('발생합니다 결제', 755),
#  ('발송', 756),
#  ('발송처리는', 757),
#  ('발송했어요', 758),
#  ('발송했어요 상품을', 759),
#  ('발행', 760),
#  ('발행이', 761),
#  ('발행이 가능한', 762),
#  ('방문하셔서', 763),
#  ('방문하셔서 신청을', 764),
#  ('방문하여', 765),
#  ('방문하여 무통장', 766),
#  ('방문하여 입금', 767),
#  ('방문합니다', 768),
#  ('방문합니다 직접', 769),
#  ('방법', 770),
#  ('방법 선택', 771),
#  ('방법으로', 772),
#  ('방법으로 결제', 773),
#  ('방법을', 774),
#  ('방법을 선택해', 775),
#  ('방법이', 776),
#  ('방법이 다릅니다아래', 777),
#  ('방지해주는', 778),
#  ('방지해주는 서비스입니다참고사항', 779),
#  ('배송', 780),
#  ('배송 교환의', 781),
#  ('배송 되지', 782),
#  ('배송 사고는', 783),
#  ('배송 상품과', 784),
#  ('배송 완료', 785),
#  ('배송 적립금', 786),
#  ('배송 조회', 787),
#  ('배송 중픽업', 788),
#  ('배송 진행', 789),
#  ('배송비는', 790),
#  ('배송비를', 791),
#  ('배송비를 선결제해야', 792),
#  ('배송완료로', 793),
#  ('배송완료로 확인', 794),
#  ('배송으로', 795),
#  ('배송으로 반품이', 796),
#  ('배송이', 797),
#  ('배송이 됩니다', 798),
#  ('배송이 됩니다브랜드가', 799),
#  ('배송조회', 800),
#  ('배송조회 택배사', 801),
#  ('배송조회는', 802),
#  ('배송조회는 해당', 803),
#  ('배송조회에서도', 804),
#  ('배송조회에서도 배송완료로', 805),
#  ('배송지', 806),
#  ('배송지 검색이', 807),
#  ('배송진행', 808),
#  ('배송진행 상황을', 809),
#  ('뱅킹', 810),
#  ('뱅킹 계좌이체', 811),
#  ('뱅킹 뱅킹', 812),
#  ('번거로우시더라도', 813),
#  ('번거로우시더라도 각각', 814),
#  ('번에', 815),
#  ('번에 결제할', 816),
#  ('번호가', 817),
#  ('번호가 아직', 818),
#  ('번호는', 819),
#  ('번호는 아래를', 820),
#  ('번호를', 821),
#  ('변경', 822),
#  ('변경 요청을', 823),
#  ('변경되어', 824),
#  ('변경되어 있지', 825),
#  ('변경됩니다', 826),
#  ('변경됩니다 기준위', 827),
#  ('변경하고', 828),
#  ('변동에', 829),
#  ('변동에 따른', 830),
#  ('별도', 831),
#  ('별도 비밀번호를', 832),
#  ('별도로', 833),
#  ('병행수입', 834),
#  ('병행수입 상품의', 835),
#  ('병행수입 업체를', 836),
#  ('보관', 837),
#  ('보관 문의로', 838),
#  ('보관 하지', 839),
#  ('보상해드리지', 840),
#  ('보상해드리지 않습니다', 841),
#  ('보상해드립니다일부', 842),
#  ('보상해드립니다일부 브랜드의', 843),
#  ('보유하고', 844),
#  ('보증서가', 845),
#  ('보증서가 동봉됩니다', 846),
#  ('복합결제는', 847),
#  ('복합결제는 현재', 848),
#  ('본사', 849),
#  ('본사 혹은', 850),
#  ('본사가', 851),
#  ('본사가 가지는', 852),
#  ('본사에서', 853),
#  ('본사에서 제공하는', 854),
#  ('본사와', 855),
#  ('본사와 계약하여', 856),
#  ('본인을', 857),
#  ('본인을 확인함으로써', 858),
#  ('부과되어', 859),
#  ('부과되어 청구됩니다', 860),
#  ('부분', 861),
#  ('부분 환불', 862),
#  ('부분배송', 863),
#  ('부여되는', 864),
#  ('부여되는 주소이므로', 865),
#  ('부탁', 866),
#  ('부탁 드립니다', 867),
#  ('부탁드립니다', 868),
#  ('부탁드립니다 발행이', 869),
#  ('부탁드립니다주소가', 870),
#  ('부탁드립니다주소가 등록되어', 871),
#  ('분실분실했다는', 872),
#  ('분실분실했다는 택배사', 873),
#  ('분은', 874),
#  ('분은 신분증을', 875),
#  ('불가능', 876),
#  ('불가능합니다', 877),
#  ('불가능합니다 주소지는', 878),
#  ('불가하므로', 879),
#  ('불가하므로 통장', 880),
#  ('불가합니다', 881),
#  ('불가합니다 무신사', 882),
#  ('불가합니다 문의하고자', 883),
#  ('불가합니다 번거로우시더라도', 884),
#  ('불구하고', 885),
#  ('불구하고 구매하신', 886),
#  ('불량', 887),
#  ('불량 오배송인', 888),
#  ('브랜드', 889),
#  ('브랜드 박스', 890),
#  ('브랜드 본사', 891),
#  ('브랜드 본사와', 892),
#  ('브랜드 상품에', 893),
#  ('브랜드 상품이라도', 894),
#  ('브랜드 최상위', 895),
#  ('브랜드의', 896),
#  ('브랜드의 경우', 897),
#  ('브랜드의 정책에', 898),
#  ('비밀글로', 899),
#  ('비밀글로 문의해', 900),
#  ('비밀글로 전환될', 901),
#  ('비밀번호', 902),
#  ('비밀번호 입력', 903),
#  ('비밀번호를', 904),
#  ('비밀번호를 입력하여', 905),
#  ('비밀번호만으로', 906),
#  ('비밀번호만으로 안전한', 907),
#  ('비방', 908),
#  ('비방 회원', 909),
#  ('빠른', 910),
#  ('사고', 911),
#  ('사고 접수', 912),
#  ('사고는', 913),
#  ('사고는 상황에', 914),
#  ('사례', 915),
#  ('사례 발생', 916),
#  ('사실', 917),
#  ('사실 관계', 918),
#  ('사실 확인을', 919),
#  ('사안에', 920),
#  ('사안에 대한', 921),
#  ('사용', 922),
#  ('사용 기기', 923),
#  ('사용 등의', 924),
#  ('사용 흔적', 925),
#  ('사용하는', 926),
#  ('사용하는 통장', 927),
#  ('사용하시는', 928),
#  ('사용하시는 공인인증번호를', 929),
#  ('사유로', 930),
#  ('사유로 교환', 931),
#  ('사유에', 932),
#  ('사유에 의한', 933),
#  ('사유에 해당', 934),
#  ('사은품', 935),
#  ('사은품 사용', 936),
#  ('사은품 정보에서', 937),
#  ('사은품이', 938),
#  ('사은품이 해당', 939),
#  ('사이즈', 940),
#  ('사이즈 배송', 941),
#  ('사이트', 942),
#  ('사이트에', 943),
#  ('사이트에 등록되어', 944),
#  ('사이트에서', 945),
#  ('사이트에서 검색되는', 946),
#  ('사전에', 947),
#  ('사전에 서비스', 948),
#  ('사진과', 949),
#  ('사진과 함께', 950),
#  ('사진을', 951),
#  ('사진을 접수해', 952),
#  ('사항을', 953),
#  ('사항을 남겨주시면브랜드', 954),
#  ('삼성외환신한현대롯데하나씨티', 955),
#  ('삼성외환신한현대롯데하나씨티 인증방식', 956),
#  ('상관없이', 957),
#  ('상관없이 결제', 958),
#  ('상단', 959),
#  ('상대적으로', 960),
#  ('상대적으로 낮은', 961),
#  ('상세', 962),
#  ('상세 내역에서는', 963),
#  ('상세 페이지', 964),
#  ('상세 페이지의', 965),
#  ('상에서의', 966),
#  ('상에서의 카드', 967),
#  ('상태', 968),
#  ('상태 그대로', 969),
#  ('상태 그대로를', 970),
#  ('상품', 971),
#  ('상품 무료', 972),
#  ('상품 문의', 973),
#  ('상품 분실분실했다는', 974),
#  ('상품 상세', 975),
#  ('상품 이미지는', 976),
#  ('상품 인정', 977),
#  ('상품 재입고', 978),
#  ('상품 정보', 979),
#  ('상품 정보에서', 980),
#  ('상품 주문', 981),
#  ('상품 출고', 982),
#  ('상품 파손택배', 983),
#  ('상품 판매', 984),
#  ('상품 판매를', 985),
#  ('상품 회수', 986),
#  ('상품과', 987),
#  ('상품과 관련', 988),
#  ('상품과 관련된', 989),
#  ('상품구매가격의', 990),
#  ('상품구매가격의 보상해드립니다일부', 991),
#  ('상품구성품', 992),
#  ('상품구성품 누락브랜드', 993),
#  ('상품명의', 994),
#  ('상품명의 옵션으로만', 995),
#  ('상품문의', 996),
#  ('상품문의 게시판을', 997),
#  ('상품에', 998),
#  ('상품에 따라', 999),
#  ...]

# %%
train_tfidf_df = tfidf.transform(X_train)
train_tfidf_df
# Out:
# <476x2196 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39536 stored elements in Compressed Sparse Row format>

# %%
test_tfidf_df = tfidf.transform(X_test)
test_tfidf_df
# Out:
# <119x2196 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9505 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

SA_lr = LogisticRegression(random_state = 0)

# %%
SA_lr.fit(train_tfidf_df, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
test_predict = SA_lr.predict(test_tfidf_df)

# %%
from sklearn.metrics import accuracy_score

print('감성 분석 정확도 : ', round(accuracy_score(y_test, test_predict), 3))
# Out:
# 감성 분석 정확도 :  0.723

# %%
st = "언제와요"

# %%
st2 = re.sub(r'[^ ㄱ-ㅎ|가-힣]+', "", st)
st2
# Out:
# '언제와요'

# %%
st_tfidf_df = tfidf.transform([st2])
st_tfidf_df
# Out:
# <1x2196 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
st2_predict = SA_lr.predict(st_tfidf_df)
st2_predict, st2_predict[0]
# Out:
# (array([2]), 2)

# %%
import pickle
import joblib

# %%
saved_model = pickle.dumps(SA_lr)

# %%
lr_from_pickle = pickle.loads(saved_model)

# %%
lr_from_pickle.predict(tfidf.transform(["언제오나요"]))
# Out:
# array([2])

# %%
joblib.dump(SA_lr, 'spam_ham_lr.pkl')
# Out:
# ['spam_ham_lr.pkl']

# %%
def b (a):
    st2 = re.sub(r'[^ ㄱ-ㅎ|가-힣]+', "", a)
    st_tfidf_df = tfidf.transform([st2]) #벡터화
    st2_predict = SA_lr.predict(st_tfidf_df)
    if(st2_predict== 0):
        print(st2 , "->> 배송")
    elif(st2_predict== 1):
        print(st2 , "->> 상품관련")
    elif(st2_predict== 2):
        print(st2 , "->> 주문")
    else :
        print(st2 , "->> 회원")
# 0-> 배송 1-> 상품관련 2-> 주문 3->회원

# %%
st = input("문장입력:")
b(st)
# Out:
# 문장입력:아이디가 뭐였는지 까먹었
# 아이디가 뭐였는지 까먹었 ->> 주문
