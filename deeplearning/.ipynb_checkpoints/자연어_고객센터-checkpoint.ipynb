# %%
import pandas as pd
import warnings
warnings.filterwarnings(action='ignore')
import re
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import rc
import matplotlib.font_manager as fm
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(5)
import matplotlib.pyplot as plt
fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '../NanumSquareRoundEB.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
df=pd.read_csv('cs_data1.csv') #cs5로 하면 67 data1로하면 73
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      594 non-null    object
#  1   분류      595 non-null    object
# dtypes: object(2)
# memory usage: 9.4+ KB

# %%
#라벨인코딩
encoder=LabelEncoder()
df['분류'].unique()
encoder.fit(df['분류'].unique())
target=encoder.transform(df['분류'])

df['분류']= target
df['분류']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 590    3
# 591    3
# 592    3
# 593    3
# 594    3
# Name: 분류, Length: 595, dtype: int32

# %%
df
# Out:
#                                                     제목  분류
# 0                                        해외에서 주문하고 싶어요   0
# 1                                해외배송의 배송 기간은 어떻게 되나요?   0
# 2                                      해외카드 결제가 가능한가요?   0
# 3    ['\nA\n★ 주문시 꼭 기재하실 정보 : 우편번호  영문주소  영문이름  해외 ...   0
# 4    ['\nA\n업체에서 출고이후 넉넉하게 7~15일 정도 안내드리고 있으며  \n지역...   0
# ..                                                 ...  ..
# 590  ['\n\n사뿐 가족이 되시면 다양한 혜택이 있으십니다.\n주문 및 배송 교환 반품...   3
# 591  ['\n\n사뿐은 회원이 아니셔도 주문 가능하십니다.\n상품을 CART(장바구니)에...   3
# 592  ['\n\n아이디를 잊어버렸을경우\n로그인-회원아이디 찾기-이름 이메일 입력-아이디...   3
# 593  ['\n\n전화번호 및 주소등 개인정보 변경을 원하실때는\n상단에 마이페이지-회원정...   3
# 594  ['\n\n회원탈퇴는 로그인 후 마이페이지에서 가능하십니다.\n탈퇴시 현재 보유하고...   3
#
# [595 rows x 2 columns]

# %%
encoder.classes_
# Out:
# array(['배송', '상품관련', '주문', '회원'], dtype=object)

# %%
test_labels = ['배송','주문'] 
print(test_labels, '->', encoder.transform(test_labels))
# Out:
# ['배송', '주문'] -> [0 2]

# %% [markdown]
# 0-> 배송
# 1-> 상품관련
# 2-> 주문
# 3->회원

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제목      594 non-null    object
#  1   분류      595 non-null    int32
# dtypes: int32(1), object(1)
# memory usage: 7.1+ KB

# %%
df['분류'].value_counts().plot(kind='bar')

# %%
import re#규칙을 가지고 필터링해주는

# %%
df['제목'] = df['제목'].apply(lambda x: re.sub(r'[^ ㄱ-ㅣ가-힣]+', "", str(x)))

#ㄱ-|가-힣 한글이 아닌것은 다 뺴라

# %%
df.head()
# Out:
#                                                   제목  분류
# 0                                      해외에서 주문하고 싶어요   0
# 1                               해외배송의 배송 기간은 어떻게 되나요   0
# 2                                     해외카드 결제가 가능한가요   0
# 3   주문시 꼭 기재하실 정보  우편번호  영문주소  영문이름  해외 연락처 해외배송 ...   0
# 4  업체에서 출고이후 넉넉하게 일 정도 안내드리고 있으며  지역에 따라 소요기간은 다른...   0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Okt

okt = Okt()

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df =3, max_df = 0.9)
tfidf
# Out:
# TfidfVectorizer(max_df=0.9, min_df=3, ngram_range=(1, 2))

# %%
X_train, X_test, y_train, y_test = train_test_split(df['제목'], df['분류'], test_size=0.2, random_state=42)

# %%
X_train.head()
y_train.head()
# Out:
# 211    2
# 426    2
# 519    2
# 137    1
# 593    3
# Name: 분류, dtype: int32

# %%
X_test.head()
# Out:
# 188                           적립금으로 구매시 구매금액의 적립금이 적용되나요
# 238    자동입금확인 프로그램으로 입금확인이 되기 때문에 입금 후 분 정도 시간이 소요되십니...
# 462                                      주문이 자동 취소 되어있어요
# 465    주문 후 일 이내 미입금 시 가상계좌가 무효 처리되어 입금이 불가합니다 예시 일 주...
# 182                                          배송메세지가 뭔가요
# Name: 제목, dtype: object

# %%
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(max_df=0.9, min_df=3, ngram_range=(1, 2))

# %%
sorted(tfidf.vocabulary_.items())
# Out:
# [('가격으로', 0),
#  ('가격으로 수입하여', 1),
#  ('가격의', 2),
#  ('가격의 변동에', 3),
#  ('가능', 4),
#  ('가능 만원', 5),
#  ('가능 한가요', 6),
#  ('가능 한도를', 7),
#  ('가능 합니다', 8),
#  ('가능 합니다대한통운', 9),
#  ('가능 회원', 10),
#  ('가능하며', 11),
#  ('가능하지', 12),
#  ('가능하지 않습니다', 13),
#  ('가능하지 않으니', 14),
#  ('가능한', 15),
#  ('가능한 기간은', 16),
#  ('가능한가요', 17),
#  ('가능함', 18),
#  ('가능함 만원', 19),
#  ('가능합니다', 20),
#  ('가능합니다 교환', 21),
#  ('가능합니다 상품은', 22),
#  ('가능합니다 주문', 23),
#  ('가능합니다 품절된', 24),
#  ('가능합니다 해당', 25),
#  ('가능합니다년도', 26),
#  ('가능합니다년도 출생자의', 27),
#  ('가능합니다단', 28),
#  ('가능합니다단 결제', 29),
#  ('가능합니다인터넷', 30),
#  ('가능합니다인터넷 뱅킹', 31),
#  ('가립니다', 32),
#  ('가립니다 해당', 33),
#  ('가상', 34),
#  ('가상 계좌', 35),
#  ('가상계좌', 36),
#  ('가상계좌 입금', 37),
#  ('가상계좌 주문', 38),
#  ('가상계좌 주문이', 39),
#  ('가상계좌가', 40),
#  ('가상계좌는', 41),
#  ('가상계좌는 고객님께만', 42),
#  ('가상계좌로', 43),
#  ('가상의', 44),
#  ('가상의 인터넷안전결제', 45),
#  ('가입', 46),
#  ('가입 기본', 47),
#  ('가입인증', 48),
#  ('가장', 49),
#  ('가장 정확합니다', 50),
#  ('가지는', 51),
#  ('가지는 것이', 52),
#  ('가지의', 53),
#  ('가지의 결제수단을', 54),
#  ('가치가', 55),
#  ('가치가 현저히', 56),
#  ('가품으로', 57),
#  ('가품으로 판명될', 58),
#  ('각각', 59),
#  ('각각 배송이', 60),
#  ('각각 입금해주셔야', 61),
#  ('감소하는', 62),
#  ('감소하는 경우', 63),
#  ('같은', 64),
#  ('같은 경우에는', 65),
#  ('같은 브랜드', 66),
#  ('같은 택배사로', 67),
#  ('같은 확인', 68),
#  ('같이', 69),
#  ('같이 개봉', 70),
#  ('같이 처리합니다', 71),
#  ('개별', 72),
#  ('개봉', 73),
#  ('개봉 제품의', 74),
#  ('개인', 75),
#  ('개인 정보', 76),
#  ('개인정보', 77),
#  ('개인정보 제공', 78),
#  ('거래', 79),
#  ('거래 명예훼손', 80),
#  ('거래 은행에', 81),
#  ('거슬러', 82),
#  ('거슬러 받거나', 83),
#  ('거쳐', 84),
#  ('거쳐 진위', 85),
#  ('건물명이', 86),
#  ('건물명이 검색되지', 87),
#  ('건물명이 변경되어', 88),
#  ('건물에', 89),
#  ('건물에 부여되는', 90),
#  ('건물이', 91),
#  ('건물이 있지', 92),
#  ('검색되는', 93),
#  ('검색되는 주소를', 94),
#  ('검색되지', 95),
#  ('검색되지 않을', 96),
#  ('검색을', 97),
#  ('검색을 통해', 98),
#  ('검색이', 99),
#  ('검색이 안될', 100),
#  ('검수', 101),
#  ('검수 기간은', 102),
#  ('검수 진행', 103),
#  ('검증을', 104),
#  ('검증을 거쳐', 105),
#  ('것으로', 106),
#  ('것으로 국민우리신한카드로', 107),
#  ('것으로 등이', 108),
#  ('것을', 109),
#  ('것이', 110),
#  ('것이 가장', 111),
#  ('것이 특징이며', 112),
#  ('게시판', 113),
#  ('게시판 미확인', 114),
#  ('게시판에', 115),
#  ('게시판에 게재합니다', 116),
#  ('게시판으로', 117),
#  ('게시판을', 118),
#  ('게시판을 통하여', 119),
#  ('게시판이나', 120),
#  ('게시판이나 입점', 121),
#  ('게재하도록', 122),
#  ('게재하도록 권고합니다', 123),
#  ('게재합니다', 124),
#  ('게재합니다 또한', 125),
#  ('결제', 126),
#  ('결제 가능', 127),
#  ('결제 가능합니다년도', 128),
#  ('결제 구매금액의', 129),
#  ('결제 금액의', 130),
#  ('결제 금액이', 131),
#  ('결제 대금은', 132),
#  ('결제 대금을', 133),
#  ('결제 비밀번호', 134),
#  ('결제 비밀번호를', 135),
#  ('결제 설정에서', 136),
#  ('결제 수수료를', 137),
#  ('결제 월이', 138),
#  ('결제 추가로', 139),
#  ('결제 현금영수증', 140),
#  ('결제 휴대폰', 141),
#  ('결제가', 142),
#  ('결제금액의', 143),
#  ('결제금액의 차액은', 144),
#  ('결제금액이', 145),
#  ('결제금액이 만원', 146),
#  ('결제는', 147),
#  ('결제는 국민우리신한카드사에서', 148),
#  ('결제를', 149),
#  ('결제를 진행하면', 150),
#  ('결제만', 151),
#  ('결제만 가능합니다', 152),
#  ('결제수단', 153),
#  ('결제수단 선택에서', 154),
#  ('결제수단을', 155),
#  ('결제수단을 이용하시거나', 156),
#  ('결제수단을 이용해', 157),
#  ('결제시', 158),
#  ('결제월', 159),
#  ('결제월 기준', 160),
#  ('결제의', 161),
#  ('결제의 환불', 162),
#  ('결제하나요', 163),
#  ('결제하는', 164),
#  ('결제하는 방법으로', 165),
#  ('결제한', 166),
#  ('결제할', 167),
#  ('결제할 있습니다아직', 168),
#  ('결제할 카드번호를', 169),
#  ('경동', 170),
#  ('경동 대신', 171),
#  ('경로마이페이지', 172),
#  ('경로마이페이지 배송', 173),
#  ('경로모바일앱웹', 174),
#  ('경로모바일앱웹 마이페이지', 175),
#  ('경로에서', 176),
#  ('경로에서 배송진행', 177),
#  ('경비실에', 178),
#  ('경우', 179),
#  ('경우 계좌로', 180),
#  ('경우 교환', 181),
#  ('경우 교환환불이', 182),
#  ('경우 당사', 183),
#  ('경우 도로명주소', 184),
#  ('경우 만원', 185),
#  ('경우 만원미성년자', 186),
#  ('경우 무신사는', 187),
#  ('경우 문의글로', 188),
#  ('경우 반품비가', 189),
#  ('경우 반품이', 190),
#  ('경우 본사에서', 191),
#  ('경우 브랜드', 192),
#  ('경우 브랜드의', 193),
#  ('경우 새로', 194),
#  ('경우 생일이', 195),
#  ('경우 영업점을', 196),
#  ('경우 주문', 197),
#  ('경우 평일', 198),
#  ('경우 플러그인', 199),
#  ('경우 한국', 200),
#  ('경우 해당', 201),
#  ('경우 확인해', 202),
#  ('경우 회원님을', 203),
#  ('경우가', 204),
#  ('경우는', 205),
#  ('경우는 인터넷뱅킹에', 206),
#  ('경우에는', 207),
#  ('경우에는 각각', 208),
#  ('경우에만', 209),
#  ('경우에만 주문배송픽업', 210),
#  ('경우원', 211),
#  ('경우원 단위', 212),
#  ('경위', 213),
#  ('경위 처리결과를', 214),
#  ('계속', 215),
#  ('계약을', 216),
#  ('계약을 맺고', 217),
#  ('계약하여', 218),
#  ('계약하여 한국', 219),
#  ('계좌', 220),
#  ('계좌 결제만', 221),
#  ('계좌로', 222),
#  ('계좌로 환불됩니다', 223),
#  ('계좌번호', 224),
#  ('계좌번호 등의', 225),
#  ('계좌번호 입니다', 226),
#  ('계좌이체', 227),
#  ('계좌이체 기기', 228),
#  ('계좌이체 하셔야', 229),
#  ('계좌정보로', 230),
#  ('계좌정보로 입금자', 231),
#  ('고객', 232),
#  ('고객님', 233),
#  ('고객님께', 234),
#  ('고객님께만', 235),
#  ('고객님께만 발급되는', 236),
#  ('고객님께서', 237),
#  ('고객님들께서는', 238),
#  ('고객님들께서는 가지의', 239),
#  ('고객님의', 240),
#  ('고객님이', 241),
#  ('고객님이 소유하신', 242),
#  ('고객님이 소유한', 243),
#  ('고객별', 244),
#  ('고객별 판매', 245),
#  ('고객센터', 246),
#  ('고객센터 또는', 247),
#  ('고객센터 번호는', 248),
#  ('고객센터 톡톡으로', 249),
#  ('고객센터로', 250),
#  ('고객센터로 문의', 251),
#  ('고객센터로 문의해', 252),
#  ('곳에서는', 253),
#  ('곳에서는 만나기', 254),
#  ('공개', 255),
#  ('공개 글은', 256),
#  ('공식', 257),
#  ('공식 수입원이', 258),
#  ('공인인증', 259),
#  ('공인인증 과정이', 260),
#  ('공인인증 만원', 261),
#  ('공인인증번호', 262),
#  ('공인인증번호 입력', 263),
#  ('공인인증번호를', 264),
#  ('공인인증번호를 입력하셔야', 265),
#  ('공인인증서가', 266),
#  ('공인인증서가 없으신', 267),
#  ('공인인증서를', 268),
#  ('공인인증서를 다운로드', 269),
#  ('공인인증안심클릭', 270),
#  ('공인인증안심클릭 등록방법', 271),
#  ('공지', 272),
#  ('공지 게시판에', 273),
#  ('공지 판매', 274),
#  ('과정상품', 275),
#  ('과정상품 회수', 276),
#  ('과정은', 277),
#  ('과정은 아래', 278),
#  ('과정이', 279),
#  ('과정이 필수입니다', 280),
#  ('관계', 281),
#  ('관계 확인', 282),
#  ('관련', 283),
#  ('관련 내용은노출이', 284),
#  ('관련 업체에', 285),
#  ('관련 없는', 286),
#  ('관련된', 287),
#  ('관련된 문의', 288),
#  ('관리', 289),
#  ('관리 오른쪽', 290),
#  ('광고성', 291),
#  ('광고성 등의', 292),
#  ('광범위하게', 293),
#  ('광범위하게 디자인', 294),
#  ('교체', 295),
#  ('교체 상품', 296),
#  ('교체 상품이', 297),
#  ('교환', 298),
#  ('교환 상품', 299),
#  ('교환 신청이', 300),
#  ('교환 요청', 301),
#  ('교환 요청웹', 302),
#  ('교환 접수', 303),
#  ('교환 진행', 304),
#  ('교환 진행중인', 305),
#  ('교환 환불', 306),
#  ('교환 희망', 307),
#  ('교환반품', 308),
#  ('교환시', 309),
#  ('교환은', 310),
#  ('교환은 배송', 311),
#  ('교환을', 312),
#  ('교환을 선택', 313),
#  ('교환의', 314),
#  ('교환의 경우', 315),
#  ('교환이', 316),
#  ('교환이 가능하지', 317),
#  ('교환이 불가합니다', 318),
#  ('교환처리가', 319),
#  ('교환처리가 어려운', 320),
#  ('교환환불', 321),
#  ('교환환불이', 322),
#  ('교환환불이 가능하지', 323),
#  ('구매', 324),
#  ('구매 가능', 325),
#  ('구매금액의', 326),
#  ('구매금액의 수수료가', 327),
#  ('구매를', 328),
#  ('구매를 희망하시는', 329),
#  ('구매시', 330),
#  ('구매하신', 331),
#  ('구매하신 상품이', 332),
#  ('구입하셔도', 333),
#  ('구입하셔도 됩니다위와', 334),
#  ('국가', 335),
#  ('국가 판매', 336),
#  ('국민', 337),
#  ('국민 예금주', 338),
#  ('국민우리신한카드로', 339),
#  ('국민우리신한카드로 결제할', 340),
#  ('국민우리신한카드사에서', 341),
#  ('국민우리신한카드사에서 의무적으로', 342),
#  ('국민우리신한카드안전결제', 343),
#  ('국민우리신한카드안전결제 선택', 344),
#  ('궁금해요', 345),
#  ('권고합니다', 346),
#  ('권고합니다 무신사', 347),
#  ('그대로', 348),
#  ('그대로 보관', 349),
#  ('그대로 이중으로', 350),
#  ('그대로 포장해서', 351),
#  ('그대로를', 352),
#  ('그대로를 보관', 353),
#  ('글은', 354),
#  ('글은 비밀글로', 355),
#  ('금액', 356),
#  ('금액을', 357),
#  ('금액의', 358),
#  ('금액의 단위까지', 359),
#  ('금액이', 360),
#  ('금액이 포함된', 361),
#  ('금액이 환불', 362),
#  ('기간', 363),
#  ('기간 한정', 364),
#  ('기간 한정의', 365),
#  ('기간은', 366),
#  ('기간은 결제월', 367),
#  ('기간은 평일', 368),
#  ('기간을', 369),
#  ('기간이', 370),
#  ('기간이 연장될', 371),
#  ('기기', 372),
#  ('기기 등록', 373),
#  ('기기 은행', 374),
#  ('기기 이용', 375),
#  ('기반으로', 376),
#  ('기반으로 합니다검색', 377),
#  ('기반으로 합니다띄어쓰기', 378),
#  ('기본', 379),
#  ('기본 혜택', 380),
#  ('기준', 381),
#  ('기준 소요됩니다', 382),
#  ('기준 이내', 383),
#  ('기준 이상', 384),
#  ('기준 익월', 385),
#  ('기준에', 386),
#  ('기준에 따라', 387),
#  ('기준위', 388),
#  ('기준위 한도는', 389),
#  ('기준으로', 390),
#  ('기타', 391),
#  ('까지는', 392),
#  ('까지는 평일', 393),
#  ('나머지', 394),
#  ('남겨주세요', 395),
#  ('남겨주시면', 396),
#  ('남겨주시면브랜드', 397),
#  ('남겨주시면브랜드 담당자가', 398),
#  ('남은', 399),
#  ('낮은', 400),
#  ('낮은 가격으로', 401),
#  ('내부', 402),
#  ('내부 조사를', 403),
#  ('내역', 404),
#  ('내역 조회', 405),
#  ('내역에서는', 406),
#  ('내역에서는 상품', 407),
#  ('내역이', 408),
#  ('내외부', 409),
#  ('내외부 검증을', 410),
#  ('내용', 411),
#  ('내용 참고해', 412),
#  ('내용은노출이', 413),
#  ('내용은노출이 되지', 414),
#  ('내용을', 415),
#  ('내용을 확인해', 416),
#  ('네이버', 417),
#  ('노출로', 418),
#  ('노출로 인한', 419),
#  ('누락브랜드', 420),
#  ('누락브랜드 상품에', 421),
#  ('누르시면', 422),
#  ('누릅니다', 423),
#  ('누릅니다 결제', 424),
#  ('누릅니다 발급', 425),
#  ('다르기', 426),
#  ('다르기 때문에', 427),
#  ('다르더라도', 428),
#  ('다르더라도 입금이', 429),
#  ('다르면', 430),
#  ('다르면 교환이', 431),
#  ('다르므로', 432),
#  ('다르므로 한번에', 433),
#  ('다른', 434),
#  ('다른 결제수단을', 435),
#  ('다른 곳에서는', 436),
#  ('다른 상품으로', 437),
#  ('다를', 438),
#  ('다를 경우', 439),
#  ('다를경우', 440),
#  ('다릅니다아래', 441),
#  ('다릅니다아래 내용을', 442),
#  ('다소', 443),
#  ('다시', 444),
#  ('다시 주문해주시거나', 445),
#  ('다운로드', 446),
#  ('다운로드 받아', 447),
#  ('다음', 448),
#  ('다음 단계를', 449),
#  ('다음 휴대폰', 450),
#  ('다음과', 451),
#  ('다음과 같이', 452),
#  ('다음날', 453),
#  ('다음달', 454),
#  ('다음달 일에', 455),
#  ('다음에', 456),
#  ('다음에 등록하기를', 457),
#  ('다하겠습니다', 458),
#  ('단계를', 459),
#  ('단계를 진행합니다', 460),
#  ('단독', 461),
#  ('단독 판매', 462),
#  ('단위', 463),
#  ('단위 입금이', 464),
#  ('단위까지', 465),
#  ('단위까지 맞춰야', 466),
#  ('단위까지 정확히', 467),
#  ('달라도', 468),
#  ('달라도 상품', 469),
#  ('담당자가', 470),
#  ('담당자가 직접', 471),
#  ('답변드립니다', 472),
#  ('답변드립니다 상품과', 473),
#  ('당사', 474),
#  ('당사 홈페이지', 475),
#  ('당일', 476),
#  ('대금은', 477),
#  ('대금은 다음', 478),
#  ('대금을', 479),
#  ('대금을 휴대폰으로', 480),
#  ('대기', 481),
#  ('대기 배송조회', 482),
#  ('대부분', 483),
#  ('대부분 불가합니다', 484),
#  ('대부분입니다', 485),
#  ('대부분입니다 일부', 486),
#  ('대상이', 487),
#  ('대상이 아닙니다', 488),
#  ('대상카드', 489),
#  ('대상카드 삼성외환신한현대롯데하나씨티', 490),
#  ('대신', 491),
#  ('대신 배송', 492),
#  ('대한', 493),
#  ('대한 경위', 494),
#  ('대한통운', 495),
#  ('대한통운 택배를', 496),
#  ('대해', 497),
#  ('대해 안내드립니다', 498),
#  ('도로명', 499),
#  ('도로명 조회', 500),
#  ('도로명 주소로', 501),
#  ('도로명은', 502),
#  ('도로명은 건물에', 503),
#  ('도로명주소', 504),
#  ('도로명주소 도움센터에', 505),
#  ('도와드리겠습니다', 506),
#  ('도용', 507),
#  ('도용 또는', 508),
#  ('도용 라벨', 509),
#  ('도움센터에', 510),
#  ('도움센터에 등록', 511),
#  ('도움센터에 변경', 512),
#  ('도착', 513),
#  ('도착 검수', 514),
#  ('도착까지', 515),
#  ('도착까지 평일', 516),
#  ('도착하지', 517),
#  ('도착하지 않는', 518),
#  ('동명이인이', 519),
#  ('동명이인이 많은', 520),
#  ('동봉됩니다', 521),
#  ('동봉됩니다 정식', 522),
#  ('동봉해서', 523),
#  ('동의를', 524),
#  ('동의를 체크하여', 525),
#  ('동일하게', 526),
#  ('동일한', 527),
#  ('동일한 상품명의', 528),
#  ('되고', 529),
#  ('되고 상품이', 530),
#  ('되나요', 531),
#  ('되는', 532),
#  ('되는 경우', 533),
#  ('되면', 534),
#  ('되어', 535),
#  ('되어 있어야', 536),
#  ('되어 있지', 537),
#  ('되지', 538),
#  ('되지 않는', 539),
#  ('되지 않도록', 540),
#  ('되지 않았다면', 541),
#  ('되지 않을', 542),
#  ('됩니다', 543),
#  ('됩니다 성인회원의', 544),
#  ('됩니다 주문내역조회에서', 545),
#  ('됩니다 참고사항거래금액이', 546),
#  ('됩니다브랜드가', 547),
#  ('됩니다브랜드가 달라도', 548),
#  ('됩니다위와', 549),
#  ('됩니다위와 같은', 550),
#  ('드리겠습니다', 551),
#  ('드리고', 552),
#  ('드리는', 553),
#  ('드립니다', 554),
#  ('드립니다 주문번호마다', 555),
#  ('들어갑니다', 556),
#  ('들어갑니다 결제', 557),
#  ('등급별', 558),
#  ('등급별 차등', 559),
#  ('등급별 추가', 560),
#  ('등급에', 561),
#  ('등급에 따라', 562),
#  ('등록', 563),
#  ('등록 가능', 564),
#  ('등록 가능함', 565),
#  ('등록 가능합니다', 566),
#  ('등록 여부를', 567),
#  ('등록 요청을', 568),
#  ('등록되어', 569),
#  ('등록되어 있으나', 570),
#  ('등록되어 있지', 571),
#  ('등록되지', 572),
#  ('등록되지 않습니다도로명', 573),
#  ('등록된', 574),
#  ('등록방법', 575),
#  ('등록방법 고객님이', 576),
#  ('등록이', 577),
#  ('등록이 되어', 578),
#  ('등록이 불가능합니다', 579),
#  ('등록하기를', 580),
#  ('등록하기를 선택해', 581),
#  ('등록한', 582),
#  ('등을', 583),
#  ('등을 받은', 584),
#  ('등의', 585),
#  ('등의 개인', 586),
#  ('등의 경우', 587),
#  ('등의 문의는', 588),
#  ('등의 제품과', 589),
#  ('등의 책임을', 590),
#  ('등이', 591),
#  ('등이 대부분', 592),
#  ('디자인', 593),
#  ('디자인 도용', 594),
#  ('따라', 595),
#  ('따라 결제', 596),
#  ('따라 의무', 597),
#  ('따라 조금씩', 598),
#  ('따라 처리', 599),
#  ('따라 최고', 600),
#  ('따라 출고지가', 601),
#  ('따라 한정판', 602),
#  ('따라서', 603),
#  ('따라서 주문자와', 604),
#  ('따로', 605),
#  ('따로 배송', 606),
#  ('따른', 607),
#  ('따른 차액을', 608),
#  ('때는', 609),
#  ('때는 공인인증', 610),
#  ('때문에', 611),
#  ('때문에 여러', 612),
#  ('또는', 613),
#  ('또는 가상', 614),
#  ('또는 결제', 615),
#  ('또는 고객센터로', 616),
#  ('또는 공인인증', 617),
#  ('또는 라벨', 618),
#  ('또는 소명', 619),
#  ('또는 에서도', 620),
#  ('또는 톡톡에', 621),
#  ('또는 톡톡으로', 622),
#  ('또한', 623),
#  ('또한 업체에게', 624),
#  ('뜨는', 625),
#  ('뜨는 플러그인', 626),
#  ('라벨', 627),
#  ('라벨 교체', 628),
#  ('라벨 제거', 629),
#  ('라인의', 630),
#  ('라인의 특별한', 631),
#  ('로그인', 632),
#  ('로그인 사이트', 633),
#  ('로그인이', 634),
#  ('로그인정보', 635),
#  ('로젠', 636),
#  ('로젠 우체국', 637),
#  ('로지스', 638),
#  ('로지스 경동', 639),
#  ('롯데', 640),
#  ('롯데 로젠', 641),
#  ('룸페커', 642),
#  ('마이페이지', 643),
#  ('마이페이지 정보', 644),
#  ('마이페이지 주문', 645),
#  ('마이페이지 주문내역', 646),
#  ('마이페이지 주문배송픽업', 647),
#  ('마이페이지 회원정보', 648),
#  ('마이페이지에서', 649),
#  ('만나기', 650),
#  ('만나기 힘든', 651),
#  ('만원', 652),
#  ('만원 만원까지', 653),
#  ('만원 미만', 654),
#  ('만원 이상', 655),
#  ('만원 이상인', 656),
#  ('만원 이상일', 657),
#  ('만원까지', 658),
#  ('만원까지 결제', 659),
#  ('만원미성년자', 660),
#  ('만원미성년자 회원의', 661),
#  ('많은', 662),
#  ('맞춰야', 663),
#  ('맞춰야 입금', 664),
#  ('매월', 665),
#  ('매월 제공', 666),
#  ('맺고', 667),
#  ('맺고 판매되므로', 668),
#  ('먼저', 669),
#  ('메일로', 670),
#  ('명과', 671),
#  ('명과 상관없이', 672),
#  ('명예훼손', 673),
#  ('명예훼손 쇼핑몰', 674),
#  ('모니터', 675),
#  ('모니터 환경에', 676),
#  ('모두', 677),
#  ('모든', 678),
#  ('모든 상품을', 679),
#  ('모든 제품은', 680),
#  ('목록에서', 681),
#  ('목록에서 작성할', 682),
#  ('목적으로', 683),
#  ('목적으로 공식', 684),
#  ('무단도용을', 685),
#  ('무단도용을 방지해주는', 686),
#  ('무료', 687),
#  ('무료 배송', 688),
#  ('무신사', 689),
#  ('무신사 기준에', 690),
#  ('무신사 내외부', 691),
#  ('무신사 단독', 692),
#  ('무신사 스토어', 693),
#  ('무신사 스토어가', 694),
#  ('무신사 스토어에서는', 695),
#  ('무신사 스페셜숍에서는', 696),
#  ('무신사 자동회수', 697),
#  ('무신사 커뮤니티', 698),
#  ('무신사는', 699),
#  ('무신사는 소명', 700),
#  ('무신사는 입점', 701),
#  ('무신사페이', 702),
#  ('무신사페이 카드', 703),
#  ('무엇이며', 704),
#  ('무엇이며 어떻게', 705),
#  ('무엇인가요', 706),
#  ('무통장', 707),
#  ('무통장 입금을', 708),
#  ('묶음', 709),
#  ('묶음 발송처리는', 710),
#  ('문의', 711),
#  ('문의 목록에서', 712),
#  ('문의 부탁드립니다', 713),
#  ('문의 사항을', 714),
#  ('문의글로', 715),
#  ('문의글로 주소지와', 716),
#  ('문의는', 717),
#  ('문의는 숨김', 718),
#  ('문의로', 719),
#  ('문의로 사진과', 720),
#  ('문의를', 721),
#  ('문의를 통해', 722),
#  ('문의주셔야', 723),
#  ('문의주시면', 724),
#  ('문의하고자', 725),
#  ('문의하고자 하는', 726),
#  ('문의하시는', 727),
#  ('문의하시는 것이', 728),
#  ('문의해', 729),
#  ('문의해 주세요', 730),
#  ('문의해 주시기', 731),
#  ('문자', 732),
#  ('문자가', 733),
#  ('문자를', 734),
#  ('문자를 받아보실', 735),
#  ('문자를 캡처', 736),
#  ('문제로', 737),
#  ('문제를', 738),
#  ('문제를 파악합니다', 739),
#  ('미리', 740),
#  ('미리 설정해', 741),
#  ('미만', 742),
#  ('미만 안심클릭', 743),
#  ('미확인', 744),
#  ('미확인 입금자', 745),
#  ('믿고', 746),
#  ('믿고 구입하셔도', 747),
#  ('바랍니다', 748),
#  ('바랍니다 공개', 749),
#  ('바랍니다 마이페이지', 750),
#  ('바랍니다 인터넷', 751),
#  ('바랍니다단', 752),
#  ('바랍니다단 도로명은', 753),
#  ('바랍니다도로명', 754),
#  ('바랍니다도로명 조회', 755),
#  ('바랍니다도로명 주소가', 756),
#  ('바랍니다은행에', 757),
#  ('바랍니다은행에 방문하여', 758),
#  ('바로', 759),
#  ('바로 서비스를', 760),
#  ('박스', 761),
#  ('박스 제품', 762),
#  ('박스 훼손', 763),
#  ('반복적이거나', 764),
#  ('반복적이거나 광범위하게', 765),
#  ('반복적인', 766),
#  ('반복적인 주문취소', 767),
#  ('반송장', 768),
#  ('반송장 번호가', 769),
#  ('반송장 정보는', 770),
#  ('반품', 771),
#  ('반품 도착', 772),
#  ('반품 도착까지', 773),
#  ('반품 방법을', 774),
#  ('반품 예약해야', 775),
#  ('반품비가', 776),
#  ('반품비가 발생될', 777),
#  ('반품시', 778),
#  ('반품이', 779),
#  ('반품이 가능하지', 780),
#  ('반품할', 781),
#  ('반품할 상품의', 782),
#  ('반품해', 783),
#  ('반품해 주셔야', 784),
#  ('받거나', 785),
#  ('받거나 통장으로', 786),
#  ('받아', 787),
#  ('받아 설치하시면', 788),
#  ('받아보실', 789),
#  ('받아보실 있습니다', 790),
#  ('받아본', 791),
#  ('받아본 그대로', 792),
#  ('받았는데', 793),
#  ('받았다면', 794),
#  ('받았다면 해당', 795),
#  ('받았던', 796),
#  ('받았던 상태', 797),
#  ('받으셔야됩니다', 798),
#  ('받은', 799),
#  ('받은 상태', 800),
#  ('받은 택배사와', 801),
#  ('받을', 802),
#  ('받을 있습니다타', 803),
#  ('받지', 804),
#  ('발급', 805),
#  ('발급 설정을', 806),
#  ('발급 종류', 807),
#  ('발급되는', 808),
#  ('발급되는 일회성', 809),
#  ('발급되지', 810),
#  ('발급되지 않습니다', 811),
#  ('발급된', 812),
#  ('발급된 계좌정보로', 813),
#  ('발급이', 814),
#  ('발급이 완료', 815),
#  ('발급하는', 816),
#  ('발급하는 가상의', 817),
#  ('발생', 818),
#  ('발생 다음과', 819),
#  ('발생되는', 820),
#  ('발생되는 참고', 821),
#  ('발생되어', 822),
#  ('발생될', 823),
#  ('발생될 있고', 824),
#  ('발생하는', 825),
#  ('발생하는 업체는', 826),
#  ('발생합니다', 827),
#  ('발생합니다 결제', 828),
#  ('발송', 829),
#  ('발송됩니다', 830),
#  ('발송처리는', 831),
#  ('발송처리는 어렵습니다아예', 832),
#  ('발송해', 833),
#  ('발송했어요', 834),
#  ('발송했어요 상품을', 835),
#  ('발행', 836),
#  ('발행이', 837),
#  ('발행이 가능한', 838),
#  ('방문하셔서', 839),
#  ('방문하셔서 신청을', 840),
#  ('방문하여', 841),
#  ('방문하여 무통장', 842),
#  ('방문하여 입금', 843),
#  ('방문합니다', 844),
#  ('방문합니다 직접', 845),
#  ('방문해서', 846),
#  ('방문해서 구매', 847),
#  ('방법', 848),
#  ('방법 선택', 849),
#  ('방법으로', 850),
#  ('방법으로 결제', 851),
#  ('방법을', 852),
#  ('방법을 선택해', 853),
#  ('방법이', 854),
#  ('방법이 다릅니다아래', 855),
#  ('방지해주는', 856),
#  ('방지해주는 서비스입니다참고사항', 857),
#  ('배송', 858),
#  ('배송 교환의', 859),
#  ('배송 되나요', 860),
#  ('배송 되지', 861),
#  ('배송 받으셔야됩니다', 862),
#  ('배송 사고는', 863),
#  ('배송 상품과', 864),
#  ('배송 완료', 865),
#  ('배송 일반', 866),
#  ('배송 적립금', 867),
#  ('배송 조회', 868),
#  ('배송 중픽업', 869),
#  ('배송 진행', 870),
#  ('배송되지', 871),
#  ('배송비', 872),
#  ('배송비가', 873),
#  ('배송비는', 874),
#  ('배송비를', 875),
#  ('배송비를 선결제해야', 876),
#  ('배송완료', 877),
#  ('배송완료로', 878),
#  ('배송완료로 확인', 879),
#  ('배송으로', 880),
#  ('배송으로 반품이', 881),
#  ('배송은', 882),
#  ('배송을', 883),
#  ('배송이', 884),
#  ('배송이 됩니다', 885),
#  ('배송이 됩니다브랜드가', 886),
#  ('배송조회', 887),
#  ('배송조회 택배사', 888),
#  ('배송조회는', 889),
#  ('배송조회는 해당', 890),
#  ('배송조회에서도', 891),
#  ('배송조회에서도 배송완료로', 892),
#  ('배송지', 893),
#  ('배송지 검색이', 894),
#  ('배송진행', 895),
#  ('배송진행 상황을', 896),
#  ('뱅킹', 897),
#  ('뱅킹 계좌이체', 898),
#  ('뱅킹 뱅킹', 899),
#  ('버튼을', 900),
#  ('번거로우시더라도', 901),
#  ('번거로우시더라도 각각', 902),
#  ('번에', 903),
#  ('번에 결제할', 904),
#  ('번호가', 905),
#  ('번호가 아직', 906),
#  ('번호는', 907),
#  ('번호는 아래를', 908),
#  ('번호를', 909),
#  ('변경', 910),
#  ('변경 요청을', 911),
#  ('변경되어', 912),
#  ('변경되어 있지', 913),
#  ('변경됩니다', 914),
#  ('변경됩니다 기준위', 915),
#  ('변경이', 916),
#  ('변경처리가', 917),
#  ('변경하고', 918),
#  ('변경하고 싶어요', 919),
#  ('변경할', 920),
#  ('변동에', 921),
#  ('변동에 따른', 922),
#  ('별도', 923),
#  ('별도 비밀번호를', 924),
#  ('별도로', 925),
#  ('별도로 배송', 926),
#  ('병행수입', 927),
#  ('병행수입 상품의', 928),
#  ('병행수입 업체를', 929),
#  ('보관', 930),
#  ('보관 문의로', 931),
#  ('보관 하지', 932),
#  ('보내주세요', 933),
#  ('보내주신', 934),
#  ('보다', 935),
#  ('보상해드리지', 936),
#  ('보상해드리지 않습니다', 937),
#  ('보상해드립니다일부', 938),
#  ('보상해드립니다일부 브랜드의', 939),
#  ('보유하고', 940),
#  ('보유하고 있는', 941),
#  ('보증서가', 942),
#  ('보증서가 동봉됩니다', 943),
#  ('복합결제는', 944),
#  ('복합결제는 현재', 945),
#  ('본사', 946),
#  ('본사 혹은', 947),
#  ('본사가', 948),
#  ('본사가 가지는', 949),
#  ('본사에서', 950),
#  ('본사에서 제공하는', 951),
#  ('본사와', 952),
#  ('본사와 계약하여', 953),
#  ('본인을', 954),
#  ('본인을 확인함으로써', 955),
#  ('부과되어', 956),
#  ('부과되어 청구됩니다', 957),
#  ('부분', 958),
#  ('부분 환불', 959),
#  ('부분배송', 960),
#  ('부여되는', 961),
#  ('부여되는 주소이므로', 962),
#  ('부재시', 963),
#  ('부재시 경비실에', 964),
#  ('부탁', 965),
#  ('부탁 드립니다', 966),
#  ('부탁드립니다', 967),
#  ('부탁드립니다 발행이', 968),
#  ('부탁드립니다주소가', 969),
#  ('부탁드립니다주소가 등록되어', 970),
#  ('부티크', 971),
#  ('분실분실했다는', 972),
#  ('분실분실했다는 택배사', 973),
#  ('분실했어요', 974),
#  ('분은', 975),
#  ('분은 신분증을', 976),
#  ('불가', 977),
#  ('불가능', 978),
#  ('불가능하며', 979),
#  ('불가능한', 980),
#  ('불가능합니다', 981),
#  ('불가능합니다 주소지는', 982),
#  ('불가하며', 983),
#  ('불가하므로', 984),
#  ('불가하므로 통장', 985),
#  ('불가합니다', 986),
#  ('불가합니다 무신사', 987),
#  ('불가합니다 문의하고자', 988),
#  ('불가합니다 번거로우시더라도', 989),
#  ('불구하고', 990),
#  ('불구하고 구매하신', 991),
#  ('불량', 992),
#  ('불량 오배송인', 993),
#  ('브랜드', 994),
#  ('브랜드 박스', 995),
#  ('브랜드 본사', 996),
#  ('브랜드 본사와', 997),
#  ('브랜드 상품에', 998),
#  ('브랜드 상품이라도', 999),
#  ...]

# %%
train_tfidf_df = tfidf.transform(X_train)
train_tfidf_df
# Out:
# <476x2493 sparse matrix of type '<class 'numpy.float64'>'
# 	with 40522 stored elements in Compressed Sparse Row format>

# %%
test_tfidf_df = tfidf.transform(X_test)
test_tfidf_df
# Out:
# <119x2493 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9699 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

SA_lr = LogisticRegression(random_state = 45)

# %%
SA_lr.fit(train_tfidf_df, y_train)
# Out:
# LogisticRegression(random_state=45)

# %%
test_predict = SA_lr.predict(test_tfidf_df)

# %%
from sklearn.metrics import accuracy_score

print('감성 분석 정확도 : ', round(accuracy_score(y_test, test_predict), 3))
# Out:
# 감성 분석 정확도 :  0.756

# %%
st = "언제와요"

# %%
st2 = re.sub(r'[^ ㄱ-ㅎ|가-힣]+', "", st)
st2
# Out:
# '언제와요'

# %%
st_tfidf_df = tfidf.transform([st2])
st_tfidf_df
# Out:
# <1x2493 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
st2_predict = SA_lr.predict(st_tfidf_df)
st2_predict, st2_predict[0]
# Out:
# (array([2]), 2)

# %%
import pickle
import joblib

# %%
saved_model = pickle.dumps(SA_lr)

# %%
lr_from_pickle = pickle.loads(saved_model)

# %%
lr_from_pickle.predict(tfidf.transform(["언제오나요"]))
# Out:
# array([2])

# %%
joblib.dump(SA_lr, 'spam_ham_lr.pkl')
# Out:
# ['spam_ham_lr.pkl']

# %%
def b (a):
    st2 = re.sub(r'[^ ㄱ-ㅎ|가-힣]+', "", a)
    st_tfidf_df = tfidf.transform([st2]) #벡터화
    st2_predict = SA_lr.predict(st_tfidf_df)
    if(st2_predict== 0):
        print(st2 , "->> 배송")
    elif(st2_predict== 1):
        print(st2 , "->> 상품관련")
    elif(st2_predict== 2):
        print(st2 , "->> 주문")
    else :
        print(st2 , "->> 회원")
# 0-> 배송 1-> 상품관련 2-> 주문 3->회원

# %%
st = input("문장입력:")
b(st)
# Out:
# 문장입력:회원 정보 수정
# 회원 정보 수정 ->> 회원
