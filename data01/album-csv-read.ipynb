# %%
import pandas as pd
album = pd.read_csv('album.csv', encoding='euc-kr')

album
# Out:
#                                                 title                brand  price percent
# 0                      SAVAGE [미니 1집] [SYNK DIVE VER]           AESPA(에스파)  16300     19%
# 1   ODDINARY [MINI ALBUM] [SCANNING/ MASK OFF VER]...  STRAY KIDS(스트레이 키즈)  16300     19%
# 2       2021 WINTER SMTOWN: SMCU EXPRESS [RED VELVET]     RED VELVET(레드벨벳)  13400     19%
# 3   2021 WINTER SMTOWN: SMCU EXPRESS [NCT - DAYTIM...             NCT(엔시티)  13400     19%
# 4   2021 WINTER SMTOWN: SMCU EXPRESS [NCT - NIGHTT...             NCT(엔시티)  13400     19%
# 5       2021 WINTER SMTOWN: SMCU EXPRESS [SMTOWN VER]              VARIOUS  31200     19%
# 6            2021 WINTER SMTOWN: SMCU EXPRESS [AESPA]           AESPA(에스파)  13400     19%
# 7                  YOUNG-LUV.COM [미니 2집] [2종 중 랜덤 1종]          STAYC(스테이씨)  19300     20%
# 8                                      AN ODE [정규 3집]       SEVENTEEN(세븐틴)  17100     19%
# ...

# %%
album['title'][:5]
# Out:
# 0                       SAVAGE [미니 1집] [SYNK DIVE VER]
# 1    ODDINARY [MINI ALBUM] [SCANNING/ MASK OFF VER]...
# 2        2021 WINTER SMTOWN: SMCU EXPRESS [RED VELVET]
# 3    2021 WINTER SMTOWN: SMCU EXPRESS [NCT - DAYTIM...
# 4    2021 WINTER SMTOWN: SMCU EXPRESS [NCT - NIGHTT...
# Name: title, dtype: object
