# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib import rc, font_manager

# %%
from google.colab import drive 
#colab이 설치되어있는 리눅스에 구글 드라이브를 연결해야함 
drive.mount('/content/content')
# Out:
# Drive already mounted at /content/content; to attempt to forcibly remount, call drive.mount("/content/content", force_remount=True).

# %%
import matplotlib.font_manager as fm 

#fm._rebuild()
#fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '/content/content/MyDrive/NanumSquareRoundEB.ttf'
#plt.rc('font', family='NanumGothic') # For Windows
#font_location = 'C:/Windows/Fonts/malgun.ttf'#윈도우안에있는 폰트파일주소.
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
subway = pd.read_csv('/content/content/MyDrive/subway_people_analysis.csv', encoding='euc-kr')
subway
# Out:
#                 날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  \
# 0       2020-01-01  1호선   150  서울역  승차       356            280
# 1       2020-01-01  1호선   150  서울역  하차       235            952
# 2       2020-01-01  1호선   151   시청  승차       105            118
# 3       2020-01-01  1호선   151   시청  하차        81            223
# 4       2020-01-01  1호선   152   종각  승차       798            366
# ...            ...  ...   ...  ...  ..       ...            ...
# 202275  2020-12-31  8호선  2825   신흥  하차        31             95
# 202276  2020-12-31  8호선  2826   수진  승차       112            203
# 202277  2020-12-31  8호선  2826   수진  하차        15             70
# 202278  2020-12-31  8호선  2827   모란  승차        49             88
# 202279  2020-12-31  8호선  2827   모란  하차        15             59
#
#         07:00 ~ 08:00  08:00 ~ 09:00  09:00 ~ 10:00  ...  15:00 ~ 16:00  \
# 0                 313            774            923  ...           2972
# 1                 828           1043           1694  ...           2286
# 2                 123            206            318  ...            873
# 3                 334            570            611  ...            885
# 4                 198            236            310  ...           1636
# ...               ...            ...            ...  ...            ...
# 202275             78            211            145  ...            341
# 202276            475            641            311  ...            210
# 202277             92            227            190  ...            296
# 202278            246            314            176  ...            282
# 202279            111            181            142  ...            163
#
#         16:00 ~ 17:00  17:00 ~ 18:00  18:00 ~ 19:00  19:00 ~ 20:00  \
# 0                3194           3342           3002           2857
# 1                2354           2261           1922           1696
# 2                1019           1234           1383           1271
# 3                 783            849            602            435
# 4                1748           1890           1879           1827
# ...               ...            ...            ...            ...
# 202275            341            381            428            292
# 202276            236            226            223            121
# 202277            309            300            372            296
# 202278            234            261            282            140
# 202279            183            228            183            162
#
#         20:00 ~ 21:00  21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후
# 0                2311           2523           1830            987        25
# 1                1620           1181            768            426        77
# 2                1061            991            572            217         2
# 3                 293            273            174            149        26
# 4                1955           1800           1259            406         6
# ...               ...            ...            ...            ...       ...
# 202275            229            219             85             42         0
# 202276             90            109             35             19         0
# 202277            232            202            127             45         0
# 202278             86            112             45              6         0
# 202279             71             99             39             25         3
#
# [202280 rows x 25 columns]

# %%
df1 = subway.copy()
df1
# Out:
#                 날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  \
# 0       2020-01-01  1호선   150  서울역  승차       356            280
# 1       2020-01-01  1호선   150  서울역  하차       235            952
# 2       2020-01-01  1호선   151   시청  승차       105            118
# 3       2020-01-01  1호선   151   시청  하차        81            223
# 4       2020-01-01  1호선   152   종각  승차       798            366
# ...            ...  ...   ...  ...  ..       ...            ...
# 202275  2020-12-31  8호선  2825   신흥  하차        31             95
# 202276  2020-12-31  8호선  2826   수진  승차       112            203
# 202277  2020-12-31  8호선  2826   수진  하차        15             70
# 202278  2020-12-31  8호선  2827   모란  승차        49             88
# 202279  2020-12-31  8호선  2827   모란  하차        15             59
#
#         07:00 ~ 08:00  08:00 ~ 09:00  09:00 ~ 10:00  ...  15:00 ~ 16:00  \
# 0                 313            774            923  ...           2972
# 1                 828           1043           1694  ...           2286
# 2                 123            206            318  ...            873
# 3                 334            570            611  ...            885
# 4                 198            236            310  ...           1636
# ...               ...            ...            ...  ...            ...
# 202275             78            211            145  ...            341
# 202276            475            641            311  ...            210
# 202277             92            227            190  ...            296
# 202278            246            314            176  ...            282
# 202279            111            181            142  ...            163
#
#         16:00 ~ 17:00  17:00 ~ 18:00  18:00 ~ 19:00  19:00 ~ 20:00  \
# 0                3194           3342           3002           2857
# 1                2354           2261           1922           1696
# 2                1019           1234           1383           1271
# 3                 783            849            602            435
# 4                1748           1890           1879           1827
# ...               ...            ...            ...            ...
# 202275            341            381            428            292
# 202276            236            226            223            121
# 202277            309            300            372            296
# 202278            234            261            282            140
# 202279            183            228            183            162
#
#         20:00 ~ 21:00  21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후
# 0                2311           2523           1830            987        25
# 1                1620           1181            768            426        77
# 2                1061            991            572            217         2
# 3                 293            273            174            149        26
# 4                1955           1800           1259            406         6
# ...               ...            ...            ...            ...       ...
# 202275            229            219             85             42         0
# 202276             90            109             35             19         0
# 202277            232            202            127             45         0
# 202278             86            112             45              6         0
# 202279             71             99             39             25         3
#
# [202280 rows x 25 columns]

# %%
df1.dtypes
# Out:
# 날짜               object
# 호선               object
# 역번호               int64
# 역명               object
# 구분               object
# 06:00 이전          int64
# 06:00 ~ 07:00     int64
# 07:00 ~ 08:00     int64
# 08:00 ~ 09:00     int64
# 09:00 ~ 10:00     int64
# 10:00 ~ 11:00     int64
# 11:00 ~ 12:00     int64
# 12:00 ~ 13:00     int64
# 13:00 ~ 14:00     int64
# 14:00 ~ 15:00     int64
# 15:00 ~ 16:00     int64
# 16:00 ~ 17:00     int64
# 17:00 ~ 18:00     int64
# 18:00 ~ 19:00     int64
# 19:00 ~ 20:00     int64
# 20:00 ~ 21:00     int64
# 21:00 ~ 22:00     int64
# 22:00 ~ 23:00     int64
# 23:00 ~ 24:00     int64
# 24:00 이후          int64
# dtype: object

# %%
df1.info() #날짜 object로 되어있으므로 datetime으로 바꿔준다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202280 entries, 0 to 202279
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   날짜             202280 non-null  object
#  1   호선             202280 non-null  object
#  2   역번호            202280 non-null  int64
#  3   역명             202280 non-null  object
#  4   구분             202280 non-null  object
#  5   06:00 이전       202280 non-null  int64
#  6   06:00 ~ 07:00  202280 non-null  int64
#  7   07:00 ~ 08:00  202280 non-null  int64
#  8   08:00 ~ 09:00  202280 non-null  int64
#  9   09:00 ~ 10:00  202280 non-null  int64
#  10  10:00 ~ 11:00  202280 non-null  int64
#  11  11:00 ~ 12:00  202280 non-null  int64
#  12  12:00 ~ 13:00  202280 non-null  int64
#  13  13:00 ~ 14:00  202280 non-null  int64
#  14  14:00 ~ 15:00  202280 non-null  int64
#  15  15:00 ~ 16:00  202280 non-null  int64
#  16  16:00 ~ 17:00  202280 non-null  int64
#  17  17:00 ~ 18:00  202280 non-null  int64
#  18  18:00 ~ 19:00  202280 non-null  int64
#  19  19:00 ~ 20:00  202280 non-null  int64
#  20  20:00 ~ 21:00  202280 non-null  int64
#  21  21:00 ~ 22:00  202280 non-null  int64
#  22  22:00 ~ 23:00  202280 non-null  int64
#  23  23:00 ~ 24:00  202280 non-null  int64
#  24  24:00 이후       202280 non-null  int64
# dtypes: int64(21), object(4)
# memory usage: 38.6+ MB

# %%
df1['날짜'] = pd.to_datetime(df1['날짜'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202280 entries, 0 to 202279
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   날짜             202280 non-null  datetime64[ns]
#  1   호선             202280 non-null  object
#  2   역번호            202280 non-null  int64
#  3   역명             202280 non-null  object
#  4   구분             202280 non-null  object
#  5   06:00 이전       202280 non-null  int64
#  6   06:00 ~ 07:00  202280 non-null  int64
#  7   07:00 ~ 08:00  202280 non-null  int64
#  8   08:00 ~ 09:00  202280 non-null  int64
#  9   09:00 ~ 10:00  202280 non-null  int64
#  10  10:00 ~ 11:00  202280 non-null  int64
#  11  11:00 ~ 12:00  202280 non-null  int64
#  12  12:00 ~ 13:00  202280 non-null  int64
#  13  13:00 ~ 14:00  202280 non-null  int64
#  14  14:00 ~ 15:00  202280 non-null  int64
#  15  15:00 ~ 16:00  202280 non-null  int64
#  16  16:00 ~ 17:00  202280 non-null  int64
#  17  17:00 ~ 18:00  202280 non-null  int64
#  18  18:00 ~ 19:00  202280 non-null  int64
#  19  19:00 ~ 20:00  202280 non-null  int64
#  20  20:00 ~ 21:00  202280 non-null  int64
#  21  21:00 ~ 22:00  202280 non-null  int64
#  22  22:00 ~ 23:00  202280 non-null  int64
#  23  23:00 ~ 24:00  202280 non-null  int64
#  24  24:00 이후       202280 non-null  int64
# dtypes: datetime64[ns](1), int64(21), object(3)
# memory usage: 38.6+ MB

# %%
df1['날짜'].dt.year #2020년도 데이터만 존재함을 알 수 있음.
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 202275    2020
# 202276    2020
# 202277    2020
# 202278    2020
# 202279    2020
# Name: 날짜, Length: 202280, dtype: int64

# %%
df1['날짜'].dt.month #1월~12월 까지 데이터 존재 #분기별 지하철 이용 분포도를 알 수 있음.
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 202275    12
# 202276    12
# 202277    12
# 202278    12
# 202279    12
# Name: 날짜, Length: 202280, dtype: int64

# %%
df1.drop(['역번호'], axis=1)#역 번호는 데이터 분석에 큰 영향을 미치지 않으므로 제거한다.
# Out:
#                날짜   호선   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
# 0      2020-01-01  1호선  서울역  승차       356            280            313
# 1      2020-01-01  1호선  서울역  하차       235            952            828
# 2      2020-01-01  1호선   시청  승차       105            118            123
# 3      2020-01-01  1호선   시청  하차        81            223            334
# 4      2020-01-01  1호선   종각  승차       798            366            198
# ...           ...  ...  ...  ..       ...            ...            ...
# 202275 2020-12-31  8호선   신흥  하차        31             95             78
# 202276 2020-12-31  8호선   수진  승차       112            203            475
# 202277 2020-12-31  8호선   수진  하차        15             70             92
# 202278 2020-12-31  8호선   모란  승차        49             88            246
# 202279 2020-12-31  8호선   모란  하차        15             59            111
#
#         08:00 ~ 09:00  09:00 ~ 10:00  10:00 ~ 11:00  ...  15:00 ~ 16:00  \
# 0                 774            923           1418  ...           2972
# 1                1043           1694           1655  ...           2286
# 2                 206            318            309  ...            873
# 3                 570            611            612  ...            885
# 4                 236            310            379  ...           1636
# ...               ...            ...            ...  ...            ...
# 202275            211            145            165  ...            341
# 202276            641            311            196  ...            210
# 202277            227            190            166  ...            296
# 202278            314            176            147  ...            282
# 202279            181            142            109  ...            163
#
#         16:00 ~ 17:00  17:00 ~ 18:00  18:00 ~ 19:00  19:00 ~ 20:00  \
# 0                3194           3342           3002           2857
# 1                2354           2261           1922           1696
# 2                1019           1234           1383           1271
# 3                 783            849            602            435
# 4                1748           1890           1879           1827
# ...               ...            ...            ...            ...
# 202275            341            381            428            292
# 202276            236            226            223            121
# 202277            309            300            372            296
# 202278            234            261            282            140
# 202279            183            228            183            162
#
#         20:00 ~ 21:00  21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후
# 0                2311           2523           1830            987        25
# 1                1620           1181            768            426        77
# 2                1061            991            572            217         2
# 3                 293            273            174            149        26
# 4                1955           1800           1259            406         6
# ...               ...            ...            ...            ...       ...
# 202275            229            219             85             42         0
# 202276             90            109             35             19         0
# 202277            232            202            127             45         0
# 202278             86            112             45              6         0
# 202279             71             99             39             25         3
#
# [202280 rows x 24 columns]

# %%
df1['구분'].value_counts()
# Out:
# 승차    101140
# 하차    101140
# Name: 구분, dtype: int64

# %%
#인덱스 호선, 역명로 가져오고 왔을 때의 시간대별 데이터프레임을 보고 싶음. 
df1.groupby(['호선','역명']).mean() #호선 별, 시간대마다 이용 자 수 점이랑 직선 연결된 그래프 
#df.groupby(['호선']).mean() #분기별 이용자수 x축 : 분기 y축: 이용자수 1~9호선 각 호선별 표시
# Out:
#                  역번호    06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  08:00 ~ 09:00  \
# 호선  역명
# 1호선 동대문        155.0  255.668033     247.867486     388.325137     657.588798
#     동묘앞        159.0   70.534153     118.312842     229.024590     455.218579
#     서울역        150.0  253.642077     750.501366    1855.607923    3781.114754
#     시청         151.0   88.829235     327.371585    1028.133880    2615.610656
#     신설동        156.0  187.024590     261.222678     626.722678    1362.476776
# ...              ...         ...            ...            ...            ...
# 8호선 신흥        2825.0   72.592896     129.222678     238.192623     340.349727
#     암사        2811.0  226.714481     470.424863    1299.120219    1820.079235
#     잠실(송파구청)  2815.0   52.072404     202.215847     532.714481    1309.594262
#     장지        2820.0  113.180328     381.782787    1021.983607    1571.128415
#     천호(풍납토성)  2812.0  198.769126     430.524590     890.661202    1368.497268
#
#               09:00 ~ 10:00  10:00 ~ 11:00  11:00 ~ 12:00  12:00 ~ 13:00  \
# 호선  역명
# 1호선 동대문          630.370219     577.180328     635.322404     686.562842
#     동묘앞          374.105191     409.034153     565.845628     693.222678
...
# 2020-01-02 2호선 동대문역사문화공원(DDP)          502.0     166.0
#                뚝섬                      284.0     108.5
#                문래                      410.0     124.0
#                방배                      368.5     109.0
#                봉천                      597.5     206.5
#
# [300 rows x 21 columns]

# %%
df1['분기'] = 0
df1
# Out:
#                날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
# 0      2020-01-01  1호선   150  서울역  승차       356            280            313
# 1      2020-01-01  1호선   150  서울역  하차       235            952            828
# 2      2020-01-01  1호선   151   시청  승차       105            118            123
# 3      2020-01-01  1호선   151   시청  하차        81            223            334
# 4      2020-01-01  1호선   152   종각  승차       798            366            198
# ...           ...  ...   ...  ...  ..       ...            ...            ...
# 202275 2020-12-31  8호선  2825   신흥  하차        31             95             78
# 202276 2020-12-31  8호선  2826   수진  승차       112            203            475
# 202277 2020-12-31  8호선  2826   수진  하차        15             70             92
# 202278 2020-12-31  8호선  2827   모란  승차        49             88            246
# 202279 2020-12-31  8호선  2827   모란  하차        15             59            111
#
#         08:00 ~ 09:00  09:00 ~ 10:00  ...  16:00 ~ 17:00  17:00 ~ 18:00  \
# 0                 774            923  ...           3194           3342
# 1                1043           1694  ...           2354           2261
# 2                 206            318  ...           1019           1234
# 3                 570            611  ...            783            849
# 4                 236            310  ...           1748           1890
# ...               ...            ...  ...            ...            ...
# 202275            211            145  ...            341            381
# 202276            641            311  ...            236            226
# 202277            227            190  ...            309            300
# 202278            314            176  ...            234            261
# 202279            181            142  ...            183            228
#
#         18:00 ~ 19:00  19:00 ~ 20:00  20:00 ~ 21:00  21:00 ~ 22:00  \
# 0                3002           2857           2311           2523
# 1                1922           1696           1620           1181
# 2                1383           1271           1061            991
# 3                 602            435            293            273
# 4                1879           1827           1955           1800
# ...               ...            ...            ...            ...
# 202275            428            292            229            219
# 202276            223            121             90            109
# 202277            372            296            232            202
# 202278            282            140             86            112
# 202279            183            162             71             99
#
#         22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후  분기
# 0                1830            987        25   0
# 1                 768            426        77   0
# 2                 572            217         2   0
# 3                 174            149        26   0
# 4                1259            406         6   0
# ...               ...            ...       ...  ..
# 202275             85             42         0   0
# 202276             35             19         0   0
# 202277            127             45         0   0
# 202278             45              6         0   0
# 202279             39             25         3   0
#
# [202280 rows x 26 columns]

# %%
df1['날짜']
# Out:
# 0        2020-01-01
# 1        2020-01-01
# 2        2020-01-01
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 202275   2020-12-31
# 202276   2020-12-31
# 202277   2020-12-31
# 202278   2020-12-31
# 202279   2020-12-31
# Name: 날짜, Length: 202280, dtype: datetime64[ns]

# %%
df1['날짜'].value_counts()
# Out:
# 2020-11-10    560
# 2020-11-16    558
# 2020-08-21    558
# 2020-12-07    558
# 2020-09-06    558
#              ...
# 2020-05-28    550
# 2020-05-29    550
# 2020-05-31    550
# 2020-06-01    550
# 2020-07-02    550
# Name: 날짜, Length: 366, dtype: int64

# %%
#result2 = ['1', '2', '3','4']
#index_result = []

# index1 = df[(df['날짜'] >= '2020-01-01') & (df['날짜'] <= '2020-03-31')].index #0 ~50154
# index2 = df[(df['날짜'] >= '2020-04-01') & (df['날짜'] <= '2020-06-30')].index #50154 ~100287
# index3 = df[(df['날짜'] >= '2020-07-01') & (df['날짜'] <= '2020-09-30')].index #100288~151227
# index4 = df[(df['날짜'] >= '2020-10-01') & (df['날짜'] <= '2020-12-31')].index #151228 ~ 202279 

#for x in index1:
#  df1.loc[x, '분기'] = result2[0]
#for x in index2:
#  df1.loc[x, '분기'] = result2[1]
#for x in index3:
#  df1.loc[x, '분기'] = result2[2]
#for x in index4:
#  df1.loc[x, '분기'] = result2[3]

df1.loc[0:50155,'분기'] = 1
df1.loc[50155:100288,'분기'] = 2 
df1.loc[100288:151228,'분기'] = 3
df1.loc[151228:202280,'분기']= 4 

df1
# Out:
#                날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
# 0      2020-01-01  1호선   150  서울역  승차       356            280            313
# 1      2020-01-01  1호선   150  서울역  하차       235            952            828
# 2      2020-01-01  1호선   151   시청  승차       105            118            123
# 3      2020-01-01  1호선   151   시청  하차        81            223            334
# 4      2020-01-01  1호선   152   종각  승차       798            366            198
# ...           ...  ...   ...  ...  ..       ...            ...            ...
# 202275 2020-12-31  8호선  2825   신흥  하차        31             95             78
# 202276 2020-12-31  8호선  2826   수진  승차       112            203            475
# 202277 2020-12-31  8호선  2826   수진  하차        15             70             92
# 202278 2020-12-31  8호선  2827   모란  승차        49             88            246
# 202279 2020-12-31  8호선  2827   모란  하차        15             59            111
#
#         08:00 ~ 09:00  09:00 ~ 10:00  ...  16:00 ~ 17:00  17:00 ~ 18:00  \
# 0                 774            923  ...           3194           3342
# 1                1043           1694  ...           2354           2261
# 2                 206            318  ...           1019           1234
# 3                 570            611  ...            783            849
# 4                 236            310  ...           1748           1890
# ...               ...            ...  ...            ...            ...
# 202275            211            145  ...            341            381
# 202276            641            311  ...            236            226
# 202277            227            190  ...            309            300
# 202278            314            176  ...            234            261
# 202279            181            142  ...            183            228
#
#         18:00 ~ 19:00  19:00 ~ 20:00  20:00 ~ 21:00  21:00 ~ 22:00  \
# 0                3002           2857           2311           2523
# 1                1922           1696           1620           1181
# 2                1383           1271           1061            991
# 3                 602            435            293            273
# 4                1879           1827           1955           1800
# ...               ...            ...            ...            ...
# 202275            428            292            229            219
# 202276            223            121             90            109
# 202277            372            296            232            202
# 202278            282            140             86            112
# 202279            183            162             71             99
#
#         22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후  분기
# 0                1830            987        25   1
# 1                 768            426        77   1
# 2                 572            217         2   1
# 3                 174            149        26   1
# 4                1259            406         6   1
# ...               ...            ...       ...  ..
# 202275             85             42         0   4
# 202276             35             19         0   4
# 202277            127             45         0   4
# 202278             45              6         0   4
# 202279             39             25         3   4
#
# [202280 rows x 26 columns]

# %%
df1['total_people'] = 0 #전체 사람 인원 
df1['quarter_people'] = 0 #분기별 사람 인원 

print(df1.loc[0:50155,'total_people'].sum()) #1분기
print(df1.loc[50155:100288,'total_people'].sum()) #2분기
print(df1.loc[100288:151228,'total_people'].sum()) #3분기
print(df1.loc[151228:202280,'total_people'].sum()) #4분기

df1.loc[0:50155,'quarter_people'] = 633710103 #1분기 
df1.loc[50155:100288,'quarter_people'] = 591099104 #2분기 
df1.loc[100288:151228,'quarter_people'] = 584002260 #3분기
df1.loc[151228:202280,'quarter_people']= 577774922 #4분기 

#for x in index1:
#  df1.loc[x, '분기'] = result2[0]

df1
# Out:
# 0
# 0
# 0
# 0
#                날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
#
# 0                 774            923  ...           3002           2857
# 1                1043           1694  ...           1922           1696
# 2                 206            318  ...           1383           1271
# 3                 570            611  ...            602            435
# 4                 236            310  ...           1879           1827
# ...               ...            ...  ...            ...            ...
# 202275            211            145  ...            428            292
# 202276            641            311  ...            223            121
# 202277            227            190  ...            372            296
# 202278            314            176  ...            282            140
# 202279            181            142  ...            183            162
#
#         20:00 ~ 21:00  21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후  \
# 0                2311           2523           1830            987        25
# 1                1620           1181            768            426        77
# 2                1061            991            572            217         2
# 3                 293            273            174            149        26
# 4                1955           1800           1259            406         6
# ...               ...            ...            ...            ...       ...
# 202275            229            219             85             42         0
# 202276             90            109             35             19         0
# 202277            232            202            127             45         0
# 202278             86            112             45              6         0
# 202279             71             99             39             25         3
#
#         분기  total_people  quarter_people
# 0        1         36641       633710103
# 1        1         30085       633710103
# 2        1         12212       633710103
# 3        1         10608       633710103
# 4        1         20523       633710103
# ...     ..           ...             ...
# 202275   4          3920       577774922
# 202276   4          4053       577774922
# 202277   4          3754       577774922
# 202278   4          3223       577774922
# 202279   4          2405       577774922
#
# [202280 rows x 28 columns]

# %%
#반복문으로 컬럼값 추출하기. 

# col_list = [] 
# col_list = list(df1.iloc[:,[0,2]].columns)
# col_list

# col_list = [] 
# col_list = list(az.iloc[:,3:21].columns)
# col_list
# for i in range(len(col_list)):    
#     print(i)
#     az = az.drop(col_list[i],axis=1)#axis=1이면 열 0이면 행
# az

# %% [markdown]
# # 새 섹션

# %%
df2 = df1.groupby('분기').mean()

#set2 = set(subway['호선'].values)
df2 = df2.T
#df2= df2.T

# %%
df2.reset_index(inplace=True)
df2[:3]
# Out:
# 분기          index            1            2            3            4
# 0             역번호  1630.731333  1630.944129  1635.446290  1637.648515
# 1        06:00 이전   119.273293   121.338958   119.825559   114.842474
# 2   06:00 ~ 07:00   315.651540   324.449504   322.232097   307.391052

# %%
df2.set_index('index', inplace=True)
df2[:3]
# Out:
# 분기                       1            2            3            4
# index
# 역번호            1630.731333  1630.944129  1635.446290  1637.648515
# 06:00 이전        119.273293   121.338958   119.825559   114.842474
# 06:00 ~ 07:00   315.651540   324.449504   322.232097   307.391052

# %%
df2 = df2.T
df2
# Out:
# index          역번호    06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  08:00 ~ 09:00  \
# 분기
# 1      1630.731333  119.273293     315.651540     792.102502    1456.474290
# 2      1630.944129  121.338958     324.449504     807.718349    1384.649472
# 3      1635.446290  119.825559     322.232097     809.455909    1368.743561
# 4      1637.648515  114.842474     307.391052     774.296364    1354.541448
#
# index  09:00 ~ 10:00  10:00 ~ 11:00  11:00 ~ 12:00  12:00 ~ 13:00  \
# 분기
# 1         928.669265     575.742438     544.509401     585.112631
# 2         877.595396     540.289889     503.904793     530.869986
# 3         850.697899     523.250942     491.601728     521.530271
# 4         849.611122     527.914421     495.950168     531.257502
#
# index  13:00 ~ 14:00  ...  17:00 ~ 18:00  18:00 ~ 19:00  19:00 ~ 20:00  \
# 분기                    ...
# 1         642.330735  ...     986.496222    1471.147004     994.850583
# 2         578.782399  ...     946.360341    1390.512417     912.250593
# 3         559.539301  ...     931.940440    1367.403180     874.717550
# 4         573.549342  ...     943.848292    1333.900063     843.506131
#
# index  20:00 ~ 21:00  21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00   24:00 이후  \
# 분기
# 1         639.019938     576.101007     499.423447     279.742498  77.308205
# 2         592.286358     530.233000     458.852532     240.721401  17.983683
# 3         561.104751     505.297782     417.566588     214.192835  16.071731
# 4         553.202323     507.886508     356.456260     173.023231  12.773016
#
# index  total_people  quarter_people
# 분기
# 1      13563.172266     633710103.0
# 2      12667.413979     591099104.0
# 3      12314.960934     584002260.0
# 4      12166.991871     577774922.0
#
# [4 rows x 23 columns]

# %%
time_cols = df2.filter(regex='00').columns #00을 의미하는 전체 컬럼 추출
time_cols

for i in range(len(time_cols)):#반복문 인덱스     
    #print(i) #0~19 
    df2 = df2.drop(time_cols[i],axis=1)#axis=1이면 열 0이면 행
df2

df2 =df2.drop(['역번호','total_people'],1)

df2.T
df2



#df2.drop(index=['역번호','06:00 이전','06:00 ~ 07:00','07:00 ~ 08:00','08:00 ~ 09:00','09:00 ~ 10:00','10:00 ~ 11:00','11:00 ~ 12:00','12:00 ~ 13:00','13:00 ~ 14:00','14:00 ~ 15:00','15:00 ~ 16:00','16:00 ~ 17:00','17:00 ~ 18:00','18:00 ~ 19:00','19:00 ~ 20:00','20:00 ~ 21:00','21:00 ~ 22:00','22:00 ~ 23:00','23:00 ~ 24:00','24:00 이후','total_people'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   if __name__ == '__main__':
# index  quarter_people
# 분기
# 1         633710103.0
# 2         591099104.0
# 3         584002260.0
# 4         577774922.0

# %%
df2[:]
df2.reset_index(inplace=True)
df2
# Out:
# index  분기  quarter_people
# 0       1     633710103.0
# 1       2     591099104.0
# 2       3     584002260.0
# 3       4     577774922.0

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["lines.color"] = 'r'
plt.rcParams["axes.grid"] = True
set_quarter=set(df1['분기'].values)
print(set_quarter)
quarter=list(set_quarter)
# set1 = set(df2['분기'].values)
#for i in quarter:
#  plt.plot(i, df2.iloc[0, i-1] , marker = 'o', label = i)

x= np.arange(1, 5)
print(x)
y=[]
#print(df2.iloc[0,1])
#print(df2.iloc[1,1])
#print(df2.iloc[2,1])
#print(df2.iloc[3,1])

for i in range(4):
  y += [df2.iloc[i,1]]
print(y)

plt.plot(x,y,marker ='o')
plt.xticks(np.arange(1, 5), labels=['1', '2','3','4'])
plt.title('분기별 지하철 총 인원 수')
plt.show()


#for i in range(1,5):
  #plt.scatter(i, df2['quarter_people'][i], marker ='o', label = i)
#  plt.plot(i, df2['quarter_people'][i],marker ='o', label = i)

#plt.plot()  

#plt.legend()
# Out:
# {1, 2, 3, 4}
# [1 2 3 4]
# [633710103.0, 591099104.0, 584002260.0, 577774922.0]

# %%
df3 = df1.copy()
df3
# Out:
#                날짜   호선   역번호   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
#
# 06:00 ~ 07:00  337.077322   480.651749  296.327681  395.578920  254.691545
# 07:00 ~ 08:00  831.732923  1205.539973  738.464362  941.452711  688.271980
#
# 호선                    6호선         7호선         8호선
# index
# 06:00 이전        76.829444  128.275608   98.729589
# 06:00 ~ 07:00  186.146815  311.048859  245.123835
# 07:00 ~ 08:00  467.305592  765.703739  597.351093

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.rcParams["lines.linewidth"] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = True 

#호선 별, 시간대마다 이용자수 점이랑 직선 연결된 그래프 
set1 = set(subway['호선'].values)
for i in set1:
  plt.plot(df3.index, df3[i], marker='o',label=i)
plt.title('시간대 별 지하철 호선 이용자 수') 
plt.legend()

# %%
#호선별 승하차 평균 그래프 
subway1 = subway.copy()
subway1.drop(columns = ['역번호'], inplace = True)
subway1['평균 합계'] = subway1.mean(axis=1)
subway1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
#                 날짜   호선   역명  구분  06:00 이전  06:00 ~ 07:00  07:00 ~ 08:00  \
# 0       2020-01-01  1호선  서울역  승차       356            280            313
# 1       2020-01-01  1호선  서울역  하차       235            952            828
# 2       2020-01-01  1호선   시청  승차       105            118            123
# 3       2020-01-01  1호선   시청  하차        81            223            334
# 4       2020-01-01  1호선   종각  승차       798            366            198
# ...            ...  ...  ...  ..       ...            ...            ...
# 202275  2020-12-31  8호선   신흥  하차        31             95             78
# 202276  2020-12-31  8호선   수진  승차       112            203            475
# 202277  2020-12-31  8호선   수진  하차        15             70             92
# 202278  2020-12-31  8호선   모란  승차        49             88            246
# 202279  2020-12-31  8호선   모란  하차        15             59            111
#
#         08:00 ~ 09:00  09:00 ~ 10:00  10:00 ~ 11:00  ...  16:00 ~ 17:00  \
# 0                 774            923           1418  ...           3194
# 1                1043           1694           1655  ...           2354
# 2                 206            318            309  ...           1019
# 3                 570            611            612  ...            783
# 4                 236            310            379  ...           1748
# ...               ...            ...            ...  ...            ...
# 202275            211            145            165  ...            341
# 202276            641            311            196  ...            236
# 202277            227            190            166  ...            309
# 202278            314            176            147  ...            234
# 202279            181            142            109  ...            183
#
#         17:00 ~ 18:00  18:00 ~ 19:00  19:00 ~ 20:00  20:00 ~ 21:00  \
# 0                3342           3002           2857           2311
# 1                2261           1922           1696           1620
# 2                1234           1383           1271           1061
# 3                 849            602            435            293
# 4                1890           1879           1827           1955
# ...               ...            ...            ...            ...
# 202275            381            428            292            229
# 202276            226            223            121             90
# 202277            300            372            296            232
# 202278            261            282            140             86
# 202279            228            183            162             71
#
#         21:00 ~ 22:00  22:00 ~ 23:00  23:00 ~ 24:00  24:00 이후    평균 합계
# 0                2523           1830            987        25  1832.05
# 1                1181            768            426        77  1504.25
# 2                 991            572            217         2   610.60
# 3                 273            174            149        26   530.40
# 4                1800           1259            406         6  1026.15
# ...               ...            ...            ...       ...      ...
# 202275            219             85             42         0   196.00
# 202276            109             35             19         0   202.65
# 202277            202            127             45         0   187.70
# 202278            112             45              6         0   161.15
# 202279             99             39             25         3   120.25
#
# [202280 rows x 25 columns]

# %%
df4 = subway1.groupby(['호선','구분']).mean()
li = df4.columns.values
ll = list(li)
ll #컬럼 리스트 
del ll[20]
ll
df4 = df4.drop(columns=ll) #평균합계만 남김

# %%
df4
# Out:
#               평균 합계
# 호선  구분
# 1호선 승차   920.438607
#     하차   905.777746
# 2호선 승차  1090.224863
#     하차  1105.574836
# 3호선 승차   610.478510
#     하차   610.862728
# 4호선 승차   757.036938
#     하차   762.937484
# 5호선 승차   456.279430
#     하차   451.842041
# 6호선 승차   348.493861
#     하차   342.528600
# 7호선 승차   537.815531
#     하차   529.842095
# 8호선 승차   434.260158
#     하차   435.425000

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 16 entries, ('1호선', '승차') to ('8호선', '하차')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   평균 합계   16 non-null     float64
# dtypes: float64(1)
# memory usage: 396.0+ bytes

# %%
df4 = df4.astype({'평균 합계':int})
df4
# Out:
#         평균 합계
# 호선  구분
# 1호선 승차    920
#     하차    905
# 2호선 승차   1090
#     하차   1105
# 3호선 승차    610
#     하차    610
# 4호선 승차    757
#     하차    762
# 5호선 승차    456
#     하차    451
# 6호선 승차    348
#     하차    342
# 7호선 승차    537
#     하차    529
# 8호선 승차    434
#     하차    435

# %%
set1 = set(subway['호선'].values)
set_1 = list(set1)
ride = []
quit = [] 
for i in set_1:
  ride.append(df4.loc[i,'승차'])
  quit.append(df4.loc[i,'하차'])

print(ride)
print(quit)

#ride, quit의 요소가 Series라서 그래프를 그릴 수 없음. int로 변환해주어야 한다. 

ride_list = [int(i) for i in ride]
quit_list = [int(i) for i in quit]

print(ride_list)
type(ride_list[1])
# Out:
# [평균 합계    537
# Name: (7호선, 승차), dtype: int64, 평균 합계    348
# Name: (6호선, 승차), dtype: int64, 평균 합계    757
# Name: (4호선, 승차), dtype: int64, 평균 합계    434
# Name: (8호선, 승차), dtype: int64, 평균 합계    456
# Name: (5호선, 승차), dtype: int64, 평균 합계    920
# Name: (1호선, 승차), dtype: int64, 평균 합계    610
# Name: (3호선, 승차), dtype: int64, 평균 합계    1090
# Name: (2호선, 승차), dtype: int64]
# [평균 합계    529
# Name: (7호선, 하차), dtype: int64, 평균 합계    342
# Name: (6호선, 하차), dtype: int64, 평균 합계    762
# Name: (4호선, 하차), dtype: int64, 평균 합계    435
# Name: (8호선, 하차), dtype: int64, 평균 합계    451
# Name: (5호선, 하차), dtype: int64, 평균 합계    905
# Name: (1호선, 하차), dtype: int64, 평균 합계    610
# Name: (3호선, 하차), dtype: int64, 평균 합계    1105
# Name: (2호선, 하차), dtype: int64]
# [537, 348, 757, 434, 456, 920, 610, 1090]
# int

# %%
plt.rcParams["figure.figsize"] = (30,10)
bar_width = 0.35
alpha = 0.5
# . astype (int)

N = len(set_1)
index = np.arange(N)

p1 = plt.bar(index, ride_list, bar_width, color = 'b', alpha = alpha, label='승차')
p2 = plt.bar(index+bar_width, quit_list, bar_width, color = 'r', alpha=alpha, label='하차')

plt.ylim([100,1200])
plt.title('호선별 승하차 인원', fontsize = 20)
plt.xlabel('호선', fontsize = 18)
plt.ylabel('이용자 수', fontsize = 18)
plt.xticks(index, set_1, fontsize = 15)
plt.legend((p1[0], p2[0]), ('승차','하차'), fontsize=15)
plt.show()
